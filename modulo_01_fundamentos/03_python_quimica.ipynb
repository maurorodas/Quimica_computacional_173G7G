# %% [markdown]
# # 🐍 Módulo 1: Fundamentos Computacionales
# ## Actividad 1.3: Python para Química Computacional
#
# <div align="center">
#
# **Universidad de Caldas - Departamento de Química**
# *Introducción a la Química Computacional (173G7G)*
# **Profesor:** José Mauricio Rodas Rodríguez
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/maurorodas/Quimica_computacional_173G7G/blob/main/modulo_01_fundamentos/03_python_quimica.ipynb)
#
# </div>
#
# ---
#
# ## 🎯 Objetivos de Aprendizaje
#
# Al finalizar esta actividad, serás capaz de:
# - Comprender los fundamentos de Python aplicados a la química computacional
# - Trabajar con tipos de datos y estructuras relevantes para cálculos químicos
# - Utilizar funciones y módulos para organizar código científico
# - Realizar cálculos químicos básicos con Python
# - Preparar el entorno para análisis de datos químicos
#
# ---
#
# ## 📚 ¿Por qué Python en Química Computacional?
#
# **Python** es el lenguaje de programación más utilizado en ciencia de datos y química computacional por varias razones:
#
# ### Ventajas de Python
# - 🎓 **Fácil de aprender**: Sintaxis clara y legible
# - 📚 **Bibliotecas especializadas**: NumPy, SciPy, RDKit, ASE, PySCF
# - 🔬 **Comunidad científica activa**: Constante desarrollo de herramientas
# - 🌐 **Integración**: Fácil conexión con software de química (Gaussian, ORCA, GROMACS)
# - 📊 **Visualización**: Matplotlib, Plotly, Py3Dmol
# - 🆓 **Código abierto**: Completamente gratuito
#
# ---

# %% [markdown]
# ## 1️⃣ Tipos de Datos Fundamentales
#
# Python tiene varios tipos de datos básicos que son esenciales para trabajar con información química.

# %%
# Números enteros (int)
num_atomos = 24
valencia_carbono = 4
numero_atomico_oxigeno = 8

print(f"Número de átomos: {num_atomos}")
print(f"Valencia del carbono: {valencia_carbono}")
print(f"Número atómico del oxígeno: {numero_atomico_oxigeno}")

# %%
# Números decimales (float)
masa_molecular = 180.16  # g/mol - glucosa
energia = -2145.67  # kcal/mol
temperatura = 298.15  # K
constante_avogadro = 6.022e23  # mol^-1

print(f"Masa molecular: {masa_molecular} g/mol")
print(f"Energía: {energia} kcal/mol")
print(f"Temperatura: {temperatura} K")
print(f"Constante de Avogadro: {constante_avogadro:.3e} mol^-1")

# %%
# Cadenas de texto (strings)
nombre_molecula = "Etanol"
formula = "C2H6O"
smiles = "CCO"

print(f"Molécula: {nombre_molecula}")
print(f"Fórmula: {formula}")
print(f"SMILES: {smiles}")

# %%
# Booleanos (bool) - útiles para condiciones
es_organica = True
es_aromatica = False
tiene_quiralidad = True

print(f"¿Es orgánica?: {es_organica}")
print(f"¿Es aromática?: {es_aromatica}")
print(f"¿Tiene quiralidad?: {tiene_quiralidad}")

# %% [markdown]
# ---
#
# ## 2️⃣ Estructuras de Datos
#
# Las estructuras de datos nos permiten organizar información compleja de forma eficiente.
#
# ### 📋 Listas
# Las listas son colecciones ordenadas y modificables. Son ideales para almacenar secuencias de datos químicos.

# %%
# Lista de elementos
elementos = ["H", "He", "Li", "Be", "B", "C", "N", "O", "F", "Ne"]
print(f"Primeros 10 elementos: {elementos}")

# Lista de masas atómicas (uma)
masas_atomicas = [1.008, 4.003, 6.941, 9.012, 10.81, 12.01, 14.01, 16.00, 19.00, 20.18]
print(f"Masas atómicas: {masas_atomicas}")

# Acceder a elementos
print(f"\nPrimer elemento: {elementos[0]}")
print(f"Último elemento: {elementos[-1]}")
print(f"Masa del oxígeno: {masas_atomicas[7]} uma")

# %%
# Operaciones con listas
elementos_periodo_2 = ["Li", "Be", "B", "C", "N", "O", "F", "Ne"]

# Añadir elementos
elementos_periodo_2.append("Na")  # Añade al final
print(f"Después de append: {elementos_periodo_2}")

# Eliminar el último (Na no es del periodo 2)
elementos_periodo_2.pop()
print(f"Después de pop: {elementos_periodo_2}")

# Longitud de la lista
print(f"Número de elementos en el periodo 2: {len(elementos_periodo_2)}")

# %%
# Coordenadas atómicas (lista de listas)
# Formato: [símbolo, x, y, z] en Angstroms
coordenadas_agua = [
    ["O", 0.000, 0.000, 0.119],
    ["H", 0.000, 0.757, -0.474],
    ["H", 0.000, -0.757, -0.474]
]

print("Geometría de la molécula de agua (H2O):")
for atomo in coordenadas_agua:
    print(f"{atomo[0]:2s}  {atomo[1]:8.3f}  {atomo[2]:8.3f}  {atomo[3]:8.3f}")

# %% [markdown]
# ### 📚 Diccionarios
# Los diccionarios almacenan pares clave-valor. Son perfectos para propiedades moleculares y datos estructurados.

# %%
# Base de datos de elementos (mini tabla periódica)
tabla_periodica = {
    "H": {"nombre": "Hidrógeno", "numero_atomico": 1, "masa": 1.008, "valencia": [1]},
    "C": {"nombre": "Carbono", "numero_atomico": 6, "masa": 12.01, "valencia": [4]},
    "N": {"nombre": "Nitrógeno", "numero_atomico": 7, "masa": 14.01, "valencia": [3, 5]},
    "O": {"nombre": "Oxígeno", "numero_atomico": 8, "masa": 16.00, "valencia": [2]},
}

# Consultar información
elemento = "C"
print(f"\nInformación del {elemento}:")
print(f"  Nombre: {tabla_periodica[elemento]['nombre']}")
print(f"  Z: {tabla_periodica[elemento]['numero_atomico']}")
print(f"  Masa: {tabla_periodica[elemento]['masa']} uma")
print(f"  Valencia(s): {tabla_periodica[elemento]['valencia']}")

# %% [markdown]
# ### 🎯 Tuplas
# Las tuplas son como listas pero **inmutables** (no se pueden modificar). Útiles para datos constantes.

# %%
# Coordenadas de un átomo (inmutables)
posicion_atomo = (1.234, -0.567, 2.891)
print(f"Posición del átomo: {posicion_atomo}")
print(f"Coordenada X: {posicion_atomo[0]}")
print(f"Coordenada Y: {posicion_atomo[1]}")
print(f"Coordenada Z: {posicion_atomo[2]}")

# Constantes físicas (no deben cambiar)
CONSTANTES = {
    "c": (299792458, "m/s"),  # Velocidad de la luz
    "h": (6.62607015e-34, "J·s"),  # Constante de Planck
    "R": (8.314462618, "J/(mol·K)"),  # Constante de gases
    "kB": (1.380649e-23, "J/K")  # Constante de Boltzmann
}

print(f"\nVelocidad de la luz: {CONSTANTES['c'][0]:.2e} {CONSTANTES['c'][1]}")
print(f"Constante de Planck: {CONSTANTES['h'][0]:.3e} {CONSTANTES['h'][1]}")

# %% [markdown]
# ---
#
# ## 3️⃣ Operaciones y Cálculos Químicos
#
# ### 🧮 Operadores Aritméticos

# %%
# Cálculo de masa molecular del etanol (C2H6O)
masa_C = 12.01
masa_H = 1.008
masa_O = 16.00

# Fórmula: C2H6O
masa_molecular_etanol = 2*masa_C + 6*masa_H + 1*masa_O

print(f"Masa molecular del etanol (C2H6O):")
print(f"  2 × C: {2*masa_C:.2f} uma")
print(f"  6 × H: {6*masa_H:.3f} uma")
print(f"  1 × O: {1*masa_O:.2f} uma")
print(f"  Total: {masa_molecular_etanol:.2f} g/mol")

# %%
# Conversión de unidades: eV a kcal/mol
energia_ev = 5.14  # electronvoltios
factor_conversion = 23.0609  # 1 eV = 23.0609 kcal/mol

energia_kcal = energia_ev * factor_conversion

print(f"Energía: {energia_ev} eV = {energia_kcal:.2f} kcal/mol")

# %%
# Ley de los gases ideales: PV = nRT
# Calcular el volumen de 2 moles de gas a 298 K y 1 atm

n = 2.0  # moles
R = 0.08206  # L·atm/(mol·K)
T = 298.0  # K
P = 1.0  # atm

V = (n * R * T) / P

print(f"Ley de los gases ideales (PV = nRT)")
print(f"  n = {n} mol")
print(f"  T = {T} K")
print(f"  P = {P} atm")
print(f"  R = {R} L·atm/(mol·K)")
print(f"  V = {V:.2f} L")

# %%
# Cálculo de distancia entre dos átomos
import math

# Coordenadas de dos átomos en Angstroms
atomo1 = (0.0, 0.0, 0.0)  # Origen
atomo2 = (1.5, 1.5, 0.0)

# Fórmula de distancia euclidiana: d = sqrt((x2-x1)^2 + (y2-y1)^2 + (z2-z1)^2)
distancia = math.sqrt(
    (atomo2[0] - atomo1[0])**2 + 
    (atomo2[1] - atomo1[1])**2 + 
    (atomo2[2] - atomo1[2])**2
)

print(f"Átomo 1: {atomo1}")
print(f"Átomo 2: {atomo2}")
print(f"Distancia: {distancia:.3f} Å")

# %% [markdown]
# ---
#
# ## 4️⃣ Estructuras de Control
#
# ### 🔀 Condicionales (if-elif-else)

# %%
# Clasificar un enlace según su longitud
longitud_enlace = 1.54  # Angstroms

print(f"Longitud de enlace: {longitud_enlace} Å")

if longitud_enlace < 1.2:
    tipo_enlace = "triple"
elif longitud_enlace < 1.4:
    tipo_enlace = "doble"
else:
    tipo_enlace = "simple"

print(f"Tipo de enlace: {tipo_enlace}")

# %%
# Determinar el estado de la materia según la temperatura
molecula = "Agua"
temperatura = 50  # °C
punto_fusion = 0  # °C
punto_ebullicion = 100  # °C

print(f"Molécula: {molecula}")
print(f"Temperatura: {temperatura} °C")

if temperatura < punto_fusion:
    estado = "sólido"
elif temperatura < punto_ebullicion:
    estado = "líquido"
else:
    estado = "gas"

print(f"Estado de la materia: {estado}")

# %% [markdown]
# ### 🔄 Bucles (for y while)

# %%
# Bucle for: Iterar sobre elementos
elementos = ["H", "C", "N", "O", "S", "P"]
numeros_atomicos = [1, 6, 7, 8, 16, 15]

print("Elementos comunes en moléculas orgánicas:")
for i in range(len(elementos)):
    print(f"  {elementos[i]:2s} (Z = {numeros_atomicos[i]:2d})")

# %%
# Calcular la masa molecular de una lista de átomos
atomos = ["C", "C", "H", "H", "H", "H", "H", "H"]  # Etano: C2H6

masas = {"C": 12.01, "H": 1.008, "N": 14.01, "O": 16.00}

masa_total = 0
for atomo in atomos:
    masa_total += masas[atomo]

print(f"Composición: {atomos}")
print(f"Masa molecular total: {masa_total:.2f} g/mol")

# %%
# Generar coordenadas para una cadena lineal de átomos
num_atomos = 5
separacion = 1.5  # Angstroms

print(f"Cadena lineal de {num_atomos} átomos con separación {separacion} Å:\n")
print("Átomo    X        Y        Z")
print("-" * 35)

for i in range(num_atomos):
    x = i * separacion
    y = 0.0
    z = 0.0
    print(f"  {i+1:2d}    {x:6.2f}   {y:6.2f}   {z:6.2f}")

# %% [markdown]
# ---
#
# ## 5️⃣ Funciones
#
# Las funciones permiten reutilizar código y organizar mejor nuestros programas.

# %%
# Función para calcular masa molecular
def calcular_masa_molecular(formula_dict):
    """
    Calcula la masa molecular de un compuesto.
    
    Parámetros:
    -----------
    formula_dict : dict
        Diccionario con elementos y sus cantidades
        Ejemplo: {"C": 6, "H": 12, "O": 6}
    
    Retorna:
    --------
    float : Masa molecular en g/mol
    """
    masas_atomicas = {
        "H": 1.008, "C": 12.01, "N": 14.01, "O": 16.00,
        "S": 32.06, "P": 30.97, "Cl": 35.45, "Na": 22.99
    }
    
    masa_total = 0
    for elemento, cantidad in formula_dict.items():
        masa_total += masas_atomicas[elemento] * cantidad
    
    return masa_total

# Ejemplo: Glucosa (C6H12O6)
glucosa = {"C": 6, "H": 12, "O": 6}
masa_glucosa = calcular_masa_molecular(glucosa)
print(f"Masa molecular de la glucosa: {masa_glucosa:.2f} g/mol")

# Ejemplo: Ácido acético (C2H4O2)
acido_acetico = {"C": 2, "H": 4, "O": 2}
masa_acetico = calcular_masa_molecular(acido_acetico)
print(f"Masa molecular del ácido acético: {masa_acetico:.2f} g/mol")

# %%
# Función para convertir energías
def convertir_energia(valor, unidad_origen, unidad_destino):
    """
    Convierte energía entre diferentes unidades.
    
    Unidades soportadas: eV, kcal/mol, kJ/mol, hartree
    """
    # Factores de conversión (todo a eV primero)
    a_eV = {
        "eV": 1.0,
        "kcal/mol": 0.043364,
        "kJ/mol": 0.010364,
        "hartree": 27.211
    }
    
    # Convertir a eV
    valor_eV = valor * a_eV[unidad_origen]
    
    # Convertir de eV a unidad destino
    valor_final = valor_eV / a_eV[unidad_destino]
    
    return valor_final

# Ejemplos de conversión
energia = 5.0
print(f"{energia} eV = {convertir_energia(energia, 'eV', 'kcal/mol'):.2f} kcal/mol")
print(f"{energia} eV = {convertir_energia(energia, 'eV', 'kJ/mol'):.2f} kJ/mol")
print(f"{energia} eV = {convertir_energia(energia, 'eV', 'hartree'):.4f} hartree")

# %%
# Función para calcular distancia entre átomos
def distancia_atomos(coord1, coord2):
    """
    Calcula la distancia euclidiana entre dos átomos.
    
    Parámetros:
    -----------
    coord1, coord2 : tuple
        Coordenadas (x, y, z) en Angstroms
    
    Retorna:
    --------
    float : Distancia en Angstroms
    """
    import math
    return math.sqrt(
        (coord2[0] - coord1[0])**2 + 
        (coord2[1] - coord1[1])**2 + 
        (coord2[2] - coord1[2])**2
    )

# Calcular distancia O-H en agua
O = (0.000, 0.000, 0.119)
H1 = (0.000, 0.757, -0.474)
H2 = (0.000, -0.757, -0.474)

dist_OH1 = distancia_atomos(O, H1)
dist_OH2 = distancia_atomos(O, H2)
dist_HH = distancia_atomos(H1, H2)

print("Distancias en la molécula de agua:")
print(f"  O-H1: {dist_OH1:.3f} Å")
print(f"  O-H2: {dist_OH2:.3f} Å")
print(f"  H-H:  {dist_HH:.3f} Å")

# %% [markdown]
# ---
#
# ## 6️⃣ Módulos Básicos para Química
#
# ### 📦 Módulo math

# %%
import math

# Constantes útiles
print("Constantes matemáticas:")
print(f"  π = {math.pi:.6f}")
print(f"  e = {math.e:.6f}")

# Funciones trigonométricas (útiles para geometría molecular)
angulo_grados = 109.5  # Ángulo tetraédrico
angulo_radianes = math.radians(angulo_grados)

print(f"\nÁngulo tetraédrico: {angulo_grados}°")
print(f"  En radianes: {angulo_radianes:.4f}")
print(f"  cos({angulo_grados}°) = {math.cos(angulo_radianes):.4f}")

# Logaritmos (importantes en termodinámica)
K_eq = 1000  # Constante de equilibrio
R = 8.314  # J/(mol·K)
T = 298.15  # K

# ΔG° = -RT ln(K)
delta_G = -R * T * math.log(K_eq) / 1000  # kJ/mol

print(f"\nEjemplo termodinámico:")
print(f"  K_eq = {K_eq}")
print(f"  ΔG° = {delta_G:.2f} kJ/mol")

# %% [markdown]
# ### 📊 List Comprehensions
# Una forma elegante y "pythónica" de crear listas.

# %%
# Crear una lista de cuadrados
numeros = [1, 2, 3, 4, 5]
cuadrados = [n**2 for n in numeros]
print(f"Números: {numeros}")
print(f"Cuadrados: {cuadrados}")

# Filtrar elementos
elementos_todos = ["H", "He", "Li", "Be", "B", "C", "N", "O", "F", "Ne"]
# Seleccionar solo los del segundo periodo (excluir H y He)
segundo_periodo = [elem for elem in elementos_todos if elem not in ["H", "He"]]
print(f"\nElementos del segundo periodo: {segundo_periodo}")

# Generar coordenadas
coordenadas_z = [(0, 0, z*1.5) for z in range(5)]
print(f"\nCoordenadas en eje Z:")
for i, coord in enumerate(coordenadas_z):
    print(f"  Átomo {i+1}: {coord}")

# %% [markdown]
# ---
#
# ## 7️⃣ Aplicación Práctica: Calculadora Química
#
# Vamos a crear una pequeña calculadora que combine todo lo aprendido.

# %%
class CalculadoraQuimica:
    """
    Clase para realizar cálculos químicos básicos.
    """
    
    def __init__(self):
        """Inicializa la calculadora con datos básicos."""
        self.masas_atomicas = {
            "H": 1.008, "C": 12.01, "N": 14.01, "O": 16.00,
            "S": 32.06, "P": 30.97, "Cl": 35.45, "Br": 79.90,
            "F": 19.00, "I": 126.90, "Na": 22.99, "K": 39.10
        }
        
        self.R = 8.314  # J/(mol·K)
    
    def masa_molecular(self, formula):
        """
        Calcula la masa molecular.
        formula: diccionario {"elemento": cantidad}
        """
        masa_total = sum(
            self.masas_atomicas[elem] * cant 
            for elem, cant in formula.items()
        )
        return masa_total
    
    def moles_a_gramos(self, moles, masa_molecular):
        """Convierte moles a gramos."""
        return moles * masa_molecular
    
    def gramos_a_moles(self, gramos, masa_molecular):
        """Convierte gramos a moles."""
        return gramos / masa_molecular
    
    def energia_termica(self, n_moles, T):
        """
        Calcula la energía térmica: E = (3/2) * n * R * T
        Para un gas ideal monoatómico.
        """
        return 1.5 * n_moles * self.R * T
    
    def distancia(self, coord1, coord2):
        """Calcula distancia entre dos puntos 3D."""
        import math
        return math.sqrt(sum((c2 - c1)**2 for c1, c2 in zip(coord1, coord2)))

# Crear instancia de la calculadora
calc = CalculadoraQuimica()

# Ejemplos de uso
print("=" * 50)
print("CALCULADORA QUÍMICA")
print("=" * 50)

# 1. Masa molecular del agua
agua = {"H": 2, "O": 1}
masa_agua = calc.masa_molecular(agua)
print(f"\n1. Agua (H2O):")
print(f"   Masa molecular: {masa_agua:.2f} g/mol")

# 2. Conversión de moles a gramos
moles_agua = 2.5
gramos_agua = calc.moles_a_gramos(moles_agua, masa_agua)
print(f"\n2. Conversión:")
print(f"   {moles_agua} moles de H2O = {gramos_agua:.2f} gramos")

# 3. Masa molecular del etanol
etanol = {"C": 2, "H": 6, "O": 1}
masa_etanol = calc.masa_molecular(etanol)
print(f"\n3. Etanol (C2H5OH):")
print(f"   Masa molecular: {masa_etanol:.2f} g/mol")

# 4. Conversión de gramos a moles
gramos = 50
moles = calc.gramos_a_moles(gramos, masa_etanol)
print(f"\n4. Conversión:")
print(f"   {gramos} g de etanol = {moles:.3f} moles")

# 5. Energía térmica
n = 1.0  # mol
T = 298.15  # K
E_termica = calc.energia_termica(n, T)
print(f"\n5. Energía térmica:")
print(f"   Para {n} mol a {T} K: {E_termica:.2f} J")

# 6. Distancia entre átomos
atomo1 = (0.0, 0.0, 0.0)
atomo2 = (1.54, 0.0, 0.0)
dist = calc.distancia(atomo1, atomo2)
print(f"\n6. Distancia entre átomos:")
print(f"   {atomo1} a {atomo2}")
print(f"   Distancia: {dist:.2f} Å")

# %% [markdown]
# ---
#
# ## 8️⃣ Ejercicios Propuestos
#
# ### Ejercicio 1: Masa Molecular
# Calcula la masa molecular de las siguientes moléculas:
# - Cafeína: C₈H₁₀N₄O₂
# - Aspirina: C₉H₈O₄
# - Sacarosa: C₁₂H₂₂O₁₁

# %%
# Tu código aquí
# Ejemplo:
calc = CalculadoraQuimica()

cafeina = {"C": 8, "H": 10, "N": 4, "O": 2}
# Completa para aspirina y sacarosa

# %% [markdown]
# ### Ejercicio 2: Conversiones
# Tienes 100 gramos de glucosa (C₆H₁₂O₆). Calcula:
# 1. ¿Cuántos moles son?
# 2. ¿Cuántas moléculas hay? (usa el número de Avogadro: 6.022 × 10²³)
# 3. ¿Cuántos átomos de carbono hay en total?

# %%
# Tu código aquí
glucosa = {"C": 6, "H": 12, "O": 6}
gramos_glucosa = 100
Na = 6.022e23  # número de Avogadro

# %% [markdown]
# ### Ejercicio 3: Geometría Molecular
# Dadas las coordenadas del dióxido de carbono (CO₂) en forma lineal:
# - C: (0.0, 0.0, 0.0)
# - O₁: (1.16, 0.0, 0.0)
# - O₂: (-1.16, 0.0, 0.0)
#
# Calcula:
# 1. La distancia C-O₁
# 2. La distancia C-O₂
# 3. La distancia O₁-O₂
# 4. Verifica que la molécula es lineal (distancia O₁-O₂ = 2 × distancia C-O)

# %%
# Tu código aquí
calc = CalculadoraQuimica()

C = (0.0, 0.0, 0.0)
O1 = (1.16, 0.0, 0.0)
O2 = (-1.16, 0.0, 0.0)

# %% [markdown]
# ### Ejercicio 4: Función Personalizada
# Crea una función llamada `calcular_concentracion` que:
# - Reciba: masa del soluto (g), masa molecular (g/mol), y volumen de solución (L)
# - Calcule y retorne: la concentración molar (mol/L)
#
# Prueba tu función calculando la concentración de una solución preparada con 10 g de NaCl (masa molecular = 58.44 g/mol) en 500 mL de agua.

# %%
# Tu código aquí
def calcular_concentracion(masa_soluto, masa_molecular, volumen_L):
    # Completa esta función
    pass

# %% [markdown]
# ---
#
# ## 📝 Resumen
#
# En esta actividad has aprendido:
#
# ✅ **Tipos de datos básicos**: int, float, str, bool
# ✅ **Estructuras de datos**: listas, diccionarios, tuplas
# ✅ **Operaciones aritméticas** aplicadas a química
# ✅ **Estructuras de control**: if-elif-else, for, while
# ✅ **Funciones** para reutilizar código
# ✅ **Clases** para organizar código complejo
# ✅ **Aplicaciones prácticas** en cálculos químicos
#
# ### 🎯 Próximos Pasos
#
# En las siguientes actividades aprenderás:
# - Bibliotecas científicas (NumPy, SciPy)
# - Manipulación de datos (Pandas)
# - Visualización (Matplotlib)
# - Bibliotecas especializadas en química (RDKit)
#
# ---
#
# ## 📚 Recursos Adicionales
#
# ### Documentación
# - [Python.org - Tutorial oficial](https://docs.python.org/es/3/tutorial/)
# - [Real Python - Tutoriales](https://realpython.com/)
# - [Python para científicos](https://scipy-lectures.org/)
#
# ### Libros recomendados
# - "Python Crash Course" - Eric Matthes
# - "Python for Chemists" - Jim Perkins
# - "Effective Python" - Brett Slatkin
#
# ### Práctica
# - [HackerRank - Python](https://www.hackerrank.com/domains/python)
# - [LeetCode - Python](https://leetcode.com/)
# - [Project Euler](https://projecteuler.net/) - Problemas matemáticos
#
# ---
#
# ## 💬 Notas Finales
#
# Este notebook te ha introducido a Python desde la perspectiva de la química computacional. La práctica constante es clave para dominar la programación. Te animo a:
#
# 1. 🔄 Modificar los ejemplos con tus propios datos
# 2. 🧪 Experimentar con diferentes moléculas
# 3. 📊 Resolver los ejercicios propuestos
# 4. 🔍 Investigar funciones y módulos adicionales
# 5. 💡 Crear tus propias funciones y calculadoras
#
# ---
#
# <div align="center">
#
# <div align="center">
#
# ## 🎉 ¡Felicitaciones!
#
# Has completado la **Actividad 1.3: Python para Química Computacional**
#
# **Siguiente actividad**: Scripting básico en Bash y Python
#
# [![Inicio](https://img.shields.io/badge/⬅️_Actividad_1.2-Editores_de_Texto-blue.svg)](02_editores_texto.ipynb)
# [![Next](https://img.shields.io/badge/Actividad_1.4_➡️-Scripting_Básico-green.svg)](04_scripting_basico.ipynb)
#
# ---
#
# 📚 **[Volver al Módulo 1](README.md)** | 🏠 **[Inicio del Curso](../README.md)**
#
# ---
#
# **Universidad de Caldas - Departamento de Química**
# *Química Computacional 173G7G*
#
# </div>
