# %% [markdown]
# # 📦 Módulo 1: Fundamentos Computacionales
# ## Actividad 1.8: Entornos Virtuales y Reproducibilidad Científica
#
# <div align="center">
#
# **Universidad de Caldas - Departamento de Química**
# *Introducción a la Química Computacional (173G7G)*
# **Profesor:** José Mauricio Rodas Rodríguez
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/maurorodas/Quimica_computacional_173G7G/blob/main/modulo_01_fundamentos/08_entornos_virtuales.ipynb)
#
# </div>
#
# ---
#
# ## 🎯 Objetivos de Aprendizaje
#
# Al finalizar esta actividad, serás capaz de:
# - Comprender la importancia de los entornos virtuales en ciencia computacional
# - Crear y gestionar entornos con Conda y venv
# - Documentar dependencias para proyectos reproducibles
# - Aplicar buenas prácticas de reproducibilidad científica
# - Configurar entornos específicos para proyectos de química computacional
# - Compartir código reproducible con la comunidad científica
#
# ---
#
# ## 🔬 ¿Por Qué Entornos Virtuales?
#
# ### El Problema de las Dependencias
#
# > "¡Pero en mi computadora sí funciona!"
# > — Todo científico alguna vez
#
# Imagina esta situación:
#
# ```
# Tú (2024):
#   - Python 3.11
#   - NumPy 1.26
#   - RDKit 2023.09
#   → Tu código funciona perfectamente ✅
#
# Tu colega (2024):
#   - Python 3.9
#   - NumPy 1.20
#   - RDKit 2022.03
#   → Tu código falla ❌
#
# Revisor del paper (2025):
#   - Python 3.12
#   - NumPy 2.0
#   - RDKit 2024.03
#   → Resultados diferentes ⚠️
# ```
#
# ### 📊 Casos Reales de Problemas
#
# | Problema | Ejemplo en Química Computacional | Impacto |
# |----------|-----------------------------------|---------|
# | **Versiones incompatibles** | NumPy 2.0 rompe código con NumPy 1.x | Paper no reproducible |
# | **Conflictos de dependencias** | RDKit necesita NumPy<2.0, pero TensorFlow necesita >2.0 | Instalación imposible |
# | **Código legacy** | Scripts de 2018 no funcionan en Python 3.11 | Pérdida de metodología |
# | **Plataforma específica** | Código desarrollado en Linux falla en Windows | Colaboración limitada |
#
# ### 🎯 Solución: Entornos Virtuales
#
# Un **entorno virtual** es un espacio aislado donde puedes:
# - ✅ Instalar versiones específicas de paquetes
# - ✅ Evitar conflictos entre proyectos
# - ✅ Documentar exactamente qué necesitas
# - ✅ Compartir configuración reproducible
# - ✅ Trabajar en múltiples proyectos simultáneamente
#
# ### 📈 Impacto en la Ciencia
#
# Según estudios recientes:
# - 🔴 ~70% de papers computacionales NO son completamente reproducibles
# - 🟡 ~50% por problemas de dependencias y entorno
# - 🟢 Usar entornos virtuales reduce esto a <10%
#
# > **Reproducibilidad = Ciencia de Calidad**
#
# ---

# %% [markdown]
# ## 🐍 Parte 1: Conda - El Gestor Científico
#
# ### ¿Qué es Conda?
#
# **Conda** es un gestor de paquetes y entornos diseñado específicamente para ciencia de datos y computación científica.
#
# #### Conda vs pip
#
# | Característica | Conda | pip |
# |----------------|-------|-----|
# | **Paquetes** | Python + No-Python (C, Fortran) | Solo Python |
# | **Dependencias** | Resuelve conflictos automáticamente | Puede tener conflictos |
# | **Ciencia** | Optimizado para paquetes científicos | General |
# | **Binarios** | Pre-compilados | A veces compila localmente |
# | **Química** | Canales especializados (conda-forge, rdkit) | PyPI |
#
# **Para química computacional: Conda es preferido** ✅
#
# ### Instalación de Conda
#
# #### Opción 1: Miniconda (Recomendado - ~500 MB)
#
# ```bash
# # Linux/Mac
# wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# bash Miniconda3-latest-Linux-x86_64.sh
#
# # Windows: Descargar instalador de
# # https://docs.conda.io/en/latest/miniconda.html
# ```
#
# #### Opción 2: Anaconda (Completo - ~3 GB)
#
# ```bash
# # Incluye 250+ paquetes científicos pre-instalados
# # Descargar de: https://www.anaconda.com/download
# ```
#
# **Recomendación:** Miniconda + instalar solo lo que necesitas
#
# ### Verificar Instalación

# %%
# Verificar conda (ejecutar en terminal, no en Python)
# conda --version
# conda list  # Ver paquetes instalados
# conda info  # Información del sistema

# En notebook, usar !
import sys
print(f"Python: {sys.version}")
print(f"Ejecutable: {sys.executable}")

# Verificar si estamos en un entorno conda
import os
conda_env = os.environ.get('CONDA_DEFAULT_ENV', 'base')
print(f"Entorno Conda: {conda_env}")

# %% [markdown]
# ### Crear Entornos con Conda
#
# #### Sintaxis Básica
#
# ```bash
# conda create -n NOMBRE_ENTORNO python=VERSION
# ```
#
# #### Ejemplo 1: Entorno para Mecánica Molecular

# %%
# Ejecutar en terminal:
# conda create -n mecanica_molecular python=3.11

# Instalar paquetes científicos básicos
# conda activate mecanica_molecular
# conda install numpy scipy matplotlib pandas

# Instalar paquetes de química desde conda-forge
# conda install -c conda-forge rdkit openbabel

# Verificar instalación
# conda list

# %% [markdown]
# #### Ejemplo 2: Entorno para Dinámica Molecular

# %%
# Terminal:
# conda create -n dinamica_molecular python=3.10

# conda activate dinamica_molecular
# conda install -c conda-forge mdanalysis mdtraj nglview

# Para visualización de trayectorias
# conda install -c conda-forge pymol-open-source

# Jupyter para análisis
# conda install jupyter ipykernel
# python -m ipykernel install --user --name dinamica_molecular --display-name "Python (MD)"

# %% [markdown]
# #### Ejemplo 3: Entorno para Química Cuántica

# %%
# Terminal:
# conda create -n quimica_cuantica python=3.11

# conda activate quimica_cuantica
# conda install -c conda-forge pyscf
# conda install -c conda-forge ase
# conda install -c conda-forge py3dmol

# Para machine learning en química
# conda install -c conda-forge scikit-learn
# conda install pytorch torchvision -c pytorch

# %% [markdown]
# ### Gestión de Entornos
#
# #### Comandos Esenciales
#
# ```bash
# # Listar todos los entornos
# conda env list
# conda info --envs
#
# # Activar un entorno
# conda activate nombre_entorno
#
# # Desactivar entorno actual
# conda deactivate
#
# # Ver paquetes en entorno activo
# conda list
#
# # Buscar un paquete
# conda search rdkit
#
# # Instalar paquete en entorno activo
# conda install nombre_paquete
#
# # Instalar versión específica
# conda install numpy=1.26.0
#
# # Instalar desde canal específico
# conda install -c conda-forge rdkit
#
# # Actualizar paquete
# conda update nombre_paquete
#
# # Actualizar todos los paquetes
# conda update --all
#
# # Eliminar paquete
# conda remove nombre_paquete
#
# # Eliminar entorno completo
# conda env remove -n nombre_entorno
# ```
#
# ### Exportar e Importar Entornos
#
# #### Opción 1: environment.yml (Recomendado)

# %%
# Exportar entorno completo
# conda env export > environment.yml

# El archivo environment.yml se ve así:
"""
name: mecanica_molecular
channels:
  - conda-forge
  - defaults
dependencies:
  - python=3.11
  - numpy=1.26.0
  - scipy=1.11.3
  - matplotlib=3.8.0
  - pandas=2.1.1
  - rdkit=2023.09.1
  - openbabel=3.1.1
  - jupyter=1.0.0
  - pip
  - pip:
    - some-pypi-package==1.0.0
"""

# Recrear entorno desde archivo
# conda env create -f environment.yml

# Actualizar entorno existente
# conda env update -f environment.yml --prune

# %% [markdown]
# #### Opción 2: requirements.txt (Conda + pip)

# %%
# Exportar solo paquetes pip
# conda activate mi_entorno
# pip freeze > requirements.txt

# Ejemplo de requirements.txt:
"""
numpy==1.26.0
pandas==2.1.1
matplotlib==3.8.0
rdkit==2023.9.1
"""

# Instalar desde requirements.txt
# pip install -r requirements.txt

# %% [markdown]
# ### Canales de Conda
#
# Los **canales** son repositorios de paquetes.
#
# #### Canales Importantes para Química
#
# ```bash
# # conda-forge: El más completo para ciencia
# conda install -c conda-forge rdkit
#
# # bioconda: Bioinformática y química computacional
# conda install -c bioconda openbabel
#
# # Agregar canal permanentemente
# conda config --add channels conda-forge
# conda config --set channel_priority strict
# ```
#
# #### Orden de Prioridad
#
# ```bash
# # Ver configuración de canales
# conda config --show channels
#
# # Configuración recomendada para química:
# # 1. conda-forge (primero)
# # 2. defaults
# # 3. bioconda
# ```
#
# ---

# %% [markdown]
# ## 🐍 Parte 2: venv - Entornos Nativos de Python
#
# ### ¿Cuándo Usar venv?
#
# **Usa venv cuando:**
# - ✅ Solo necesitas paquetes Python puros
# - ✅ Quieres algo ligero y nativo
# - ✅ No necesitas paquetes compilados complejos
# - ✅ Trabajas en sistemas con espacio limitado
#
# **Usa Conda cuando:**
# - ✅ Necesitas RDKit, OpenBabel, paquetes científicos
# - ✅ Trabajas con química computacional
# - ✅ Necesitas Python + R + otros lenguajes
#
# ### Crear Entorno con venv
#
# #### Linux/Mac

# %%
# Terminal:
# Crear entorno
# python3 -m venv mi_proyecto_quimica

# Activar entorno
# source mi_proyecto_quimica/bin/activate

# Verificar
# which python
# >>> /ruta/mi_proyecto_quimica/bin/python

# Instalar paquetes
# pip install numpy pandas matplotlib scipy

# Desactivar
# deactivate

# %% [markdown]
# #### Windows

# %%
# Terminal (PowerShell):
# Crear entorno
# python -m venv mi_proyecto_quimica

# Activar entorno
# .\mi_proyecto_quimica\Scripts\Activate.ps1

# Si da error de permisos:
# Set-ExecutionPolicy -ExecutionPolicy RemoteSigned -Scope CurrentUser

# En CMD (no PowerShell):
# .\mi_proyecto_quimica\Scripts\activate.bat

# Verificar
# where python

# %% [markdown]
# ### Gestionar Dependencias con venv
#
# #### requirements.txt Detallado

# %%
# Generar requirements.txt
# pip freeze > requirements.txt

# Ejemplo de requirements.txt bien documentado:
"""
# ============================================
# Proyecto: Análisis de Conformeros
# Autor: José Rodas
# Fecha: 2024-01-13
# Python: 3.11
# ============================================

# Computación científica
numpy==1.26.0
scipy==1.11.3
pandas==2.1.1

# Visualización
matplotlib==3.8.0
seaborn==0.13.0
plotly==5.17.0

# Química computacional (vía pip)
# Nota: RDKit mejor instalar con conda
py3Dmol==2.0.4

# Jupyter
jupyter==1.0.0
ipykernel==6.26.0

# Testing (solo desarrollo)
pytest==7.4.3  # dev
pytest-cov==4.1.0  # dev

# Utilidades
python-dotenv==1.0.0
tqdm==4.66.1
"""

# Instalar todo
# pip install -r requirements.txt

# Instalar excluyendo dev
# grep -v "# dev" requirements.txt | pip install -r /dev/stdin

# %% [markdown]
# #### Estructura de Proyecto con venv
#
# ```
# mi_proyecto_quimica/
# ├── .gitignore              # Ignorar venv/
# ├── README.md               # Documentación
# ├── requirements.txt        # Dependencias
# ├── environment.yml         # Alternativa conda
# ├── setup.py                # Instalación del proyecto
# ├── venv/                   # Entorno virtual (no versionar)
# ├── src/                    # Código fuente
# │   ├── __init__.py
# │   └── analisis.py
# ├── data/                   # Datos
# │   ├── raw/
# │   └── processed/
# ├── notebooks/              # Jupyter notebooks
# │   └── 01_exploracion.ipynb
# ├── tests/                  # Tests
# │   └── test_analisis.py
# └── results/                # Resultados
#     ├── figures/
#     └── tables/
# ```
#
# ---

# %% [markdown]
# ## 🔬 Parte 3: Casos de Uso en Química Computacional
#
# ### Caso 1: Proyecto de Tesis Doctoral
#
# **Escenario:** Tesis sobre análisis conformacional de fármacos
#
# #### Paso 1: Crear Entorno

# %%
# Terminal:
# conda create -n tesis_conformeros python=3.11
# conda activate tesis_conformeros

# Instalar dependencias
# conda install -c conda-forge rdkit openbabel
# conda install numpy pandas matplotlib seaborn
# conda install jupyter ipykernel
# conda install -c conda-forge py3dmol

# Registrar kernel en Jupyter
# python -m ipykernel install --user --name tesis_conformeros --display-name "Python (Tesis)"

# %% [markdown]
# #### Paso 2: Documentar en README.md
#
# ```markdown
# # Análisis Conformacional de Inhibidores de Proteasa
#
# ## Configuración del Entorno
#
# ### Opción A: Conda (Recomendado)
# ```bash
# conda env create -f environment.yml
# conda activate tesis_conformeros
# ```
#
# ### Opción B: Manual
# ```bash
# conda create -n tesis_conformeros python=3.11
# conda activate tesis_conformeros
# conda install -c conda-forge rdkit openbabel
# pip install -r requirements.txt
# ```
#
# ## Versiones Verificadas
# - Python: 3.11.5
# - RDKit: 2023.09.1
# - NumPy: 1.26.0
# - Pandas: 2.1.1
#
# ## Reproducir Análisis
# ```bash
# jupyter notebook notebooks/01_generacion_conformeros.ipynb
# ```
# ```
#
# #### Paso 3: Crear environment.yml

# %%
# Exportar entorno
# conda env export > environment.yml

# Editar para hacerlo multiplataforma:
"""
name: tesis_conformeros
channels:
  - conda-forge
  - defaults
dependencies:
  - python=3.11
  - rdkit
  - openbabel
  - numpy>=1.26
  - pandas>=2.1
  - matplotlib>=3.8
  - seaborn>=0.13
  - jupyter
  - ipykernel
  - py3dmol
  - pip
  - pip:
    - tqdm>=4.66
"""

# %% [markdown]
# ### Caso 2: Dinámica Molecular con GROMACS
#
# **Escenario:** Análisis de trayectorias de proteínas

# %%
# environment.yml especializado
"""
name: md_analysis
channels:
  - conda-forge
  - bioconda
dependencies:
  - python=3.10
  - mdanalysis
  - mdtraj
  - nglview
  - matplotlib
  - seaborn
  - jupyter
  - jupyterlab
  # Opcional: GROMACS
  - gromacs=2023.1
"""

# Crear entorno
# conda env create -f environment.yml
# conda activate md_analysis

# Habilitar extensión de nglview para Jupyter
# jupyter nbextension enable --py --sys-prefix widgetsnbextension
# jupyter nbextension enable --py --sys-prefix nglview

# %% [markdown]
# ### Caso 3: Machine Learning para Predicción de Propiedades
#
# **Escenario:** QSAR con redes neuronales

# %%
# environment.yml para ML + Química
"""
name: ml_quimica
channels:
  - conda-forge
  - pytorch
dependencies:
  - python=3.11
  # Química
  - rdkit
  - mordred  # Descriptores moleculares
  # Machine Learning
  - scikit-learn
  - pytorch
  - torchvision
  - xgboost
  - lightgbm
  # Data Science
  - pandas
  - numpy
  - matplotlib
  - seaborn
  - plotly
  # Jupyter
  - jupyter
  - ipykernel
  # Utilidades
  - tqdm
  - pip
  - pip:
    - deepchem  # Deep learning para química
    - chemprop  # Predicción de propiedades moleculares
"""

# %% [markdown]
# ### Caso 4: Múltiples Proyectos Simultáneos
#
# **Escenario:** Trabajas en varios proyectos con requisitos diferentes
#
# #### Organización Recomendada
#
# ```bash
# ~/Proyectos/
# ├── proyecto_farmaceutico/
# │   ├── environment.yml          # RDKit 2023.09
# │   └── ...
# │
# ├── proyecto_molecular_dynamics/
# │   ├── environment.yml          # MDAnalysis 2.6
# │   └── ...
# │
# └── proyecto_machine_learning/
#     ├── environment.yml          # PyTorch 2.1
#     └── ...
# ```
#
# #### Script de Activación Rápida

# %%
# activate_project.sh
"""
#!/bin/bash

# Script para activar entorno según proyecto

case "$1" in
    "farm")
        echo "Activando proyecto farmacéutico..."
        cd ~/Proyectos/proyecto_farmaceutico
        conda activate farma_rdkit
        ;;
    "md")
        echo "Activando dinámica molecular..."
        cd ~/Proyectos/proyecto_molecular_dynamics
        conda activate md_analysis
        ;;
    "ml")
        echo "Activando machine learning..."
        cd ~/Proyectos/proyecto_machine_learning
        conda activate ml_quimica
        ;;
    *)
        echo "Uso: activate_project.sh [farm|md|ml]"
        ;;
esac
"""

# Uso:
# source activate_project.sh farm

# %% [markdown]
# ---
#
# ## 📋 Parte 4: Buenas Prácticas de Reproducibilidad
#
# ### Checklist de Reproducibilidad
#
# #### 📦 Nivel 1: Básico (Mínimo Aceptable)
#
# ```markdown
# ✅ requirements.txt con versiones específicas
# ✅ README con instrucciones de instalación
# ✅ Versión de Python especificada
# ✅ .gitignore apropiado (no versionar venv/)
# ```
#
# #### 📦 Nivel 2: Intermedio (Recomendado)
#
# ```markdown
# ✅ Todo del Nivel 1
# ✅ environment.yml para conda
# ✅ Versiones de SO y dependencias del sistema documentadas
# ✅ Scripts de instalación automatizados
# ✅ Tests básicos para verificar instalación
# ✅ Datos de ejemplo incluidos
# ```
#
# #### 📦 Nivel 3: Avanzado (Publicación Científica)
#
# ```markdown
# ✅ Todo del Nivel 2
# ✅ Dockerfile para contenedor reproducible
# ✅ CI/CD con GitHub Actions
# ✅ Binder/Google Colab badge para ejecución directa
# ✅ Zenodo DOI para versión específica
# ✅ Documentación completa con readthedocs
# ✅ Versiones de hardware (CPU/GPU) especificadas
# ```
#
# ### .gitignore para Proyectos de Química

# %%
# .gitignore completo
"""
# Entornos virtuales
venv/
env/
ENV/
.venv
.conda/
*.egg-info/

# Archivos de Python
__pycache__/
*.py[cod]
*$py.class
*.so
.Python

# Jupyter Notebook
.ipynb_checkpoints/
*.ipynb_checkpoints

# Archivos grandes de datos (opcional)
*.xyz
*.pdb
*.trr
*.xtc
*.dcd
*.nc
data/raw/*.sdf

# Resultados que se pueden regenerar
results/temp/
*.log
*.out

# Archivos de configuración local
.env
config.local.yml

# IDE
.vscode/
.idea/
*.swp
*.swo

# Sistema operativo
.DS_Store
Thumbs.db

# Archivos temporales de programas
*.chk  # Gaussian checkpoints (pueden ser grandes)
*.fchk
*.wfn
slurm-*.out
```

# %% [markdown]
# ### README.md Template para Proyectos Químicos

# %%
# README_template.md
"""
# [Nombre del Proyecto]

[![Python](https://img.shields.io/badge/Python-3.11-blue.svg)](https://python.org)
[![License](https://img.shields.io/badge/License-MIT-green.svg)](LICENSE)
[![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/usuario/repo/main)

## Descripción

Breve descripción del proyecto y objetivos científicos.

## Requisitos del Sistema

- **Python:** 3.11 o superior
- **Sistema Operativo:** Linux/Mac/Windows
- **RAM:** Mínimo 8 GB
- **Espacio en disco:** ~2 GB

## Instalación

### Opción 1: Conda (Recomendado)

```bash
# Clonar repositorio
git clone https://github.com/usuario/proyecto.git
cd proyecto

# Crear entorno
conda env create -f environment.yml
conda activate nombre_entorno

# Verificar instalación
python -c "import rdkit; print(rdkit.__version__)"
```

### Opción 2: venv + pip

```bash
python -m venv venv
source venv/bin/activate  # Windows: venv\Scripts\activate
pip install -r requirements.txt
```

## Uso Rápido

```python
from src.analisis import procesar_molecula

# Ejemplo básico
resultado = procesar_molecula("data/molecula.sdf")
print(resultado)
```

## Estructura del Proyecto

```
proyecto/
├── data/              # Datos de entrada
├── src/               # Código fuente
├── notebooks/         # Jupyter notebooks
├── tests/             # Tests
└── results/           # Resultados
```

## Reproducir Resultados

```bash
# Ejecutar pipeline completo
python src/pipeline.py

# O usar notebook
jupyter notebook notebooks/analisis_completo.ipynb
```

## Versiones Verificadas

| Paquete | Versión | Notas |
|---------|---------|-------|
| Python | 3.11.5 | |
| RDKit | 2023.09.1 | Necesario |
| NumPy | 1.26.0 | |
| Pandas | 2.1.1 | |

## Citar Este Trabajo

```bibtex
@article{autor2024,
  title={Título del Paper},
  author={Autor, A. and Coautor, B.},
  journal={Journal Name},
  year={2024}
}
```

## Licencia

MIT License

## Contacto

- **Autor:** Nombre
- **Email:** email@universidad.edu
- **ORCID:** 0000-0000-0000-0000
"""

# %% [markdown]
# ### Docker: Reproducibilidad Extrema (Opcional Avanzado)
#
# Docker crea un contenedor con TODO el sistema operativo y dependencias.
#
# #### Dockerfile Ejemplo

# %%
# Dockerfile
"""
FROM continuumio/miniconda3:latest

# Información del mantenedor
LABEL maintainer="tu_email@universidad.edu"
LABEL description="Entorno para química computacional"

# Actualizar sistema
RUN apt-get update && apt-get install -y \
    gcc \
    g++ \
    git \
    && rm -rf /var/lib/apt/lists/*

# Copiar archivos de configuración
COPY environment.yml /tmp/environment.yml

# Crear entorno conda
RUN conda env create -f /tmp/environment.yml && \
    conda clean -afy

# Activar entorno por defecto
SHELL ["conda", "run", "-n", "quimica_comp", "/bin/bash", "-c"]

# Directorio de trabajo
WORKDIR /proyecto

# Puerto para Jupyter
EXPOSE 8888

# Comando por defecto
CMD ["conda", "run", "-n", "quimica_comp", "jupyter", "lab", \
     "--ip=0.0.0.0", "--port=8888", "--no-browser", "--allow-root"]
"""

# Construir imagen
# docker build -t quimica_comp:latest .

# Ejecutar contenedor
# docker run -p 8888:8888 -v $(pwd):/proyecto quimica_comp:latest

# %% [markdown]
# ### Binder: Notebooks Ejecutables en la Nube
#
# **Binder** permite que cualquiera ejecute tus notebooks sin instalar nada.
#
# #### Configuración
#
# 1. Crear repositorio público en GitHub
# 2. Agregar `environment.yml` o `requirements.txt` en la raíz
# 3. Ir a [mybinder.org](https://mybinder.org)
# 4. Pegar URL de tu repo
# 5. Copiar badge para README
#
# #### Archivos necesarios para Binder
#
# ```
# repo/
# ├── environment.yml      # O requirements.txt
# ├── postBuild           # (Opcional) comandos post-instalación
# └── notebooks/
#     └── analisis.ipynb
# ```
#
# Ejemplo de `postBuild`:
# ```bash
# #!/bin/bash
# jupyter nbextension enable --py widgetsnbextension --sys-prefix
# jupyter nbextension enable --py nglview --sys-prefix
# ```
#
# ---

# %% [markdown]
# ## 🛠️ Parte 5: Troubleshooting y Tips
#
# ### Problemas Comunes con Conda
#
# #### Problema 1: "Solving environment" tarda mucho
#
# **Solución:**
# ```bash
# # Usar mamba (solver más rápido)
# conda install -c conda-forge mamba
#
# # Usar mamba en lugar de conda
# mamba install rdkit
# mamba env create -f environment.yml
# ```
#
# #### Problema 2: Conflictos de dependencias
#
# **Solución:**
# ```bash
# # Crear entorno nuevo con dependencias especificadas
# conda create -n nuevo_env python=3.11 rdkit=2023.09 numpy=1.26
#
# # Si persiste, usar canales específicos
# conda create -n nuevo_env -c conda-forge python=3.11 rdkit numpy
# ```
#
# #### Problema 3: Entorno no se activa
#
# **Solución:**
# ```bash
# # Inicializar conda en shell
# conda init bash  # o zsh, fish, etc.
#
# # Reiniciar terminal
#
# # Si sigue sin funcionar
# source ~/miniconda3/etc/profile.d/conda.sh
# conda activate mi_entorno
# ```
#
# #### Problema 4: Paquete no encontrado
#
# **Solución:**
# ```bash
# # Buscar en diferentes canales
# conda search -c conda-forge nombre_paquete
# conda search -c bioconda nombre_paquete
#
# # Instalar con pip si no está en conda
# conda activate mi_entorno
# pip install nombre_paquete
# ```
#
# ### Problemas Comunes con venv
#
# #### Problema 1: "no se puede activar en Windows"
#
# **Solución:**
# ```powershell
# # PowerShell: cambiar política de ejecución
# Set-ExecutionPolicy -ExecutionPolicy RemoteSigned -Scope CurrentUser
#
# # O usar CMD en lugar de PowerShell
# venv\Scripts\activate.bat
# ```
#
# #### Problema 2: pip instala en sistema, no en venv
#
# **Solución:**
# ```bash
# # Verificar que estás en venv
# which pip  # Linux/Mac
# where pip  # Windows
#
# # Debería mostrar ruta dentro de venv/
# # Si no, reactivar entorno
# deactivate
# source venv/bin/activate
# ```
#
# #### Problema 3: Error al compilar paquetes
#
# **Solución:**
# ```bash
# # Instalar herramientas de compilación
# # Ubuntu/Debian
# sudo apt-get install build-essential python3-dev
#
# # Mac
# xcode-select --install
#
# # Windows: instalar Visual Studio Build Tools
# ```
#
# ### Tips Pro
#
# #### 1. Alias útiles para .bashrc o .zshrc
#
# ```bash
# # Agregar a ~/.bashrc
# alias ca='conda activate'
# alias cda='conda deactivate'
# alias cenv='conda env list'
# alias clist='conda list'
#
# # Activación rápida
# alias actesis='conda activate tesis_conformeros'
# alias acmd='conda activate md_analysis'

# %% [markdown]
# #### 2. Limpieza de Conda
#
# ```bash
# # Liberar espacio
# conda clean --all
#
# # Ver tamaño de paquetes descargados
# du -sh ~/miniconda3/pkgs/
#
# # Eliminar entornos no usados
# conda env list
# conda env remove -n entorno_viejo
# ```
#
# #### 3. Acelerar Instalaciones
#
# ```bash
# # Configurar para usar libmamba (solver rápido)
# conda install -n base conda-libmamba-solver
# conda config --set solver libmamba
#
# # O instalar mamba
# conda install -c conda-forge mamba
# mamba install rdkit  # Mucho más rápido
# ```
#
# #### 4. Verificar Compatibilidad

# %%
# Script para verificar instalación
import sys
import importlib

def verificar_entorno():
    """Verifica que todos los paquetes necesarios estén instalados."""
    
    paquetes_requeridos = {
        'numpy': '1.26.0',
        'pandas': '2.1.0',
        'matplotlib': '3.8.0',
        'rdkit': '2023.9.0',  # RDKit usa formato diferente
    }
    
    print(f"Python: {sys.version}")
    print(f"Ejecutable: {sys.executable}\n")
    print("=" * 60)
    print(f"{'Paquete':<20} {'Instalado':<15} {'Requerido':<15} {'Estado'}")
    print("=" * 60)
    
    for paquete, version_req in paquetes_requeridos.items():
        try:
            mod = importlib.import_module(paquete)
            version = getattr(mod, '__version__', 'unknown')
            
            # Comparación simple de versión (mejora: usar packaging)
            if version >= version_req or version == 'unknown':
                estado = "✅"
            else:
                estado = "⚠️"
                
            print(f"{paquete:<20} {version:<15} {version_req:<15} {estado}")
        except ImportError:
            print(f"{paquete:<20} {'NO INSTALADO':<15} {version_req:<15} ❌")
    
    print("=" * 60)

# Ejecutar verificación
verificar_entorno()

# %% [markdown]
# ---
#
# ## ✍️ Ejercicios Prácticos
#
# ### Ejercicio 1: Crear Entorno para Proyecto de Mecánica Molecular (Básico)
#
# **Objetivo:** Configurar un entorno reproducible para análisis conformacional
#
# **Tareas:**
# 1. Crear entorno conda llamado `mecanica_molecular` con Python 3.11
# 2. Instalar: numpy, pandas, matplotlib, rdkit, openbabel
# 3. Crear archivo `environment.yml`
# 4. Crear archivo `requirements.txt` equivalente
# 5. Escribir un README.md con instrucciones de instalación
#
# **Verificación:**
# ```python
# # Ejecutar en el entorno
# import rdkit
# from rdkit import Chem
# mol = Chem.MolFromSmiles('CCO')
# print(f"Molécula: {Chem.MolToMolBlock(mol)}")
# ```

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 2: Reproducir Entorno de un Paper (Intermedio)
#
# **Escenario:** Encontraste un paper interesante en GitHub con este `environment.yml`:
#
# ```yaml
# name: paper_conformers
# channels:
#   - conda-forge
# dependencies:
#   - python=3.10
#   - rdkit=2022.09
#   - numpy=1.23
#   - pandas=1.5
#   - matplotlib=3.6
# ```
#
# **Tareas:**
# 1. Crear el entorno desde el archivo
# 2. Verificar que todas las versiones son correctas
# 3. Detectar si hay incompatibilidades con tu sistema
# 4. Actualizar a versiones modernas manteniendo compatibilidad
# 5. Documentar cambios necesarios

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 3: Proyecto Multi-Entorno (Avanzado)
#
# **Escenario:** Tienes 3 proyectos simultáneos:
# - **Proyecto A:** Machine learning (PyTorch 2.0, scikit-learn)
# - **Proyecto B:** Dinámica molecular (MDAnalysis, MDTraj)
# - **Proyecto C:** Química cuántica (PySCF, ASE)
#
# **Tareas:**
# 1. Crear 3 entornos separados con sus dependencias
# 2. Escribir script bash para cambiar entre proyectos
# 3. Crear archivo `.envrc` para direnv (auto-activación)
# 4. Documentar en tabla comparativa qué paquetes usa cada uno
# 5. Identificar paquetes comunes que podrían compartirse
#
# **Bonus:** Crear entorno "base" con herramientas comunes (Jupyter, NumPy) y entornos específicos que lo extiendan.

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio 4: Publicación Reproducible (Desafío)
#
# **Objetivo:** Preparar un proyecto para publicación científica con reproducibilidad máxima
#
# **Requisitos:**
# 1. Proyecto con al menos 3 notebooks de análisis
# 2. `environment.yml` completo y testeado
# 3. `README.md` profesional con badges
# 4. `.gitignore` apropiado
# 5. Dockerfile funcional (opcional)
# 6. Configuración para Binder
# 7. Script de verificación de instalación
# 8. Tests básicos con pytest
#
# **Entregable:** Repositorio de GitHub listo para compartir con revisores de paper
#
# **Criterios de éxito:**
# - ✅ Un colega puede clonar y ejecutar en <15 minutos
# - ✅ Todos los notebooks ejecutan sin errores
# - ✅ Badge de Binder funciona
# - ✅ Tests pasan correctamente

# %%
# Tu solución aquí

# %% [markdown]
# ---
#
# ## 📚 Recursos Adicionales
#
# ### Documentación Oficial
#
# #### Conda
# - 📖 [Documentación de Conda](https://docs.conda.io/)
# - 📖 [Conda Cheat Sheet](https://docs.conda.io/projects/conda/en/latest/user-guide/cheatsheet.html)
# - 📖 [Conda-Forge](https://conda-forge.org/)
# - 📖 [Mamba Documentation](https://mamba.readthedocs.io/)
#
# #### Python venv
# - 📖 [venv - Python Docs](https://docs.python.org/3/library/venv.html)
# - 📖 [pip Documentation](https://pip.pypa.io/)
# - 📖 [virtualenv](https://virtualenv.pypa.io/)
#
# ### Herramientas de Reproducibilidad
#
# #### Gestión de Entornos
# - 🔧 [Poetry](https://python-poetry.org/) - Gestión moderna de dependencias
# - 🔧 [Pipenv](https://pipenv.pypa.io/) - pip + venv simplificado
# - 🔧 [direnv](https://direnv.net/) - Auto-activación de entornos
#
# #### Contenedores
# - 🐳 [Docker](https://www.docker.com/)
# - 🐳 [Singularity](https://sylabs.io/singularity/) - Para HPC
# - 🐳 [Docker Hub - Scientific Images](https://hub.docker.com/u/continuumio)
#
# #### Notebooks Reproducibles
# - 📓 [Binder](https://mybinder.org/)
# - 📓 [Google Colab](https://colab.research.google.com/)
# - 📓 [Jupyter Book](https://jupyterbook.org/)
# - 📓 [nbconvert](https://nbconvert.readthedocs.io/)
#
# ### Artículos y Tutoriales
#
# #### Reproducibilidad Científica
# - 📄 [Ten Simple Rules for Reproducible Computational Research](https://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1003285)
# - 📄 [The Turing Way: Guide to Reproducible Research](https://the-turing-way.netlify.app/)
# - 📄 [Reproducibility in Computational Chemistry](https://pubs.acs.org/doi/10.1021/acs.jcim.0c00274)
#
# #### Tutoriales
# - 🎓 [Managing Environments - Conda](https://conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html)
# - 🎓 [Python Packaging User Guide](https://packaging.python.org/)
# - 🎓 [Best Practices for Scientific Computing](https://journals.plos.org/plosbiology/article?id=10.1371/journal.pbio.1001745)
#
# ### Química Computacional Específica
#
# #### Repositorios Ejemplo
# - 🧪 [MolSSI Best Practices](https://github.com/MolSSI/best-practices)
# - 🧪 [Computational Chemistry Templates](https://github.com/CCPBioSim/python_and_data)
# - 🧪 [RDKit Cookbook](https://github.com/rdkit/rdkit)
#
# #### Paquetes Útiles
# - 🔬 [conda-forge/chemistry](https://github.com/conda-forge?q=chem&type=all)
# - 🔬 [bioconda](https://bioconda.github.io/)
# - 🔬 [PyPI - Chemistry](https://pypi.org/search/?q=chemistry)
#
# ### Videos y Cursos
#
# - 🎥 [Conda Tutorial - YouTube](https://www.youtube.com/results?search_query=conda+tutorial)
# - 🎥 [Python Virtual Environments](https://www.youtube.com/results?search_query=python+virtual+environments)
# - 🎥 [Docker for Scientists](https://www.youtube.com/results?search_query=docker+for+scientists)
#
# ### Herramientas de Verificación
#
# - ✅ [nbval](https://github.com/computationalmodelling/nbval) - Testing de notebooks
# - ✅ [pytest](https://pytest.org/) - Framework de testing
# - ✅ [pre-commit](https://pre-commit.com/) - Hooks de Git
# - ✅ [black](https://black.readthedocs.io/) - Formateo de código
#
# ---
#
# ## 🎓 Resumen
#
# En esta actividad has aprendido:
#
# ### ✅ **Conceptos Fundamentales**
# - Por qué los entornos virtuales son críticos para ciencia reproducible
# - Diferencias entre conda y venv
# - Cuándo usar cada herramienta
#
# ### ✅ **Conda**
# - Crear y gestionar entornos
# - Instalar paquetes desde diferentes canales
# - Exportar e importar configuraciones
# - Resolver problemas comunes
#
# ### ✅ **venv**
# - Crear entornos ligeros
# - Gestionar requirements.txt
# - Integración con pip
#
# ### ✅ **Buenas Prácticas**
# - Documentar dependencias
# - Estructurar proyectos reproducibles
# - Crear README profesionales
# - Compartir código científico
#
# ### ✅ **Casos de Uso**
# - Proyectos de tesis
# - Dinámica molecular
# - Machine learning para química
# - Múltiples proyectos simultáneos
#
# ### 🎯 **Aplicaciones en Química Computacional**
# - ⚗️ Proyectos de mecánica molecular reproducibles
# - 🧬 Análisis de trayectorias MD
# - 🤖 Predicción de propiedades con ML
# - 📊 Compartir código con comunidad científica
# - 📄 Publicaciones científicas reproducibles
#
# ---
#
# ## 💡 Próximos Pasos
#
# 1. **Practica:** Crea entornos para tus proyectos actuales
# 2. **Documenta:** Agrega environment.yml a tus repositorios existentes
# 3. **Comparte:** Publica tu código con instrucciones claras
# 4. **Mejora:** Implementa testing y CI/CD
# 5. **Aprende:** Explora Docker para reproducibilidad extrema
#
# > "La reproducibilidad no es un extra, es parte integral del método científico"
#
# ---

# %% [markdown]
# <div align="center">
#
# ## 🎉 ¡Felicitaciones!
#
# Has completado la **Actividad 1.8: Entornos Virtuales y Reproducibilidad Científica**
#
# Ahora tienes las herramientas para crear proyectos de química computacional **reproducibles y profesionales**.
#
# [![Anterior](https://img.shields.io/badge/⬅️_Actividad_1.7-Visualización_de_Datos-blue.svg)](07_visualizacion_datos.ipynb)
# [![Módulo 2](https://img.shields.io/badge/Módulo_2_➡️-Representación_Molecular-green.svg)](../modulo_02_representacion_molecular/)
#
# ---
#
# 📚 **[Volver al Módulo 1](README.md)** | 🏠 **[Inicio del Curso](../README.md)**
#
# ---
#
# **Universidad de Caldas - Departamento de Química**
# *Química Computacional 173G7G*
#
# </div>
