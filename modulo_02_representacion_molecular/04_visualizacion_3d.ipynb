# %% [markdown]
# # 🧬 Módulo 2: Representación y Visualización Molecular
# ## Actividad 2.4: Visualización 3D de Moléculas
#
# <div align="center">
#
# **Universidad de Caldas - Departamento de Química**
# *Introducción a la Química Computacional (173G7G)*
# **Profesor:** José Mauricio Rodas Rodríguez
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/maurorodas/Quimica_computacional_173G7G/blob/main/modulo_02_representacion_molecular/04_visualizacion_3d.ipynb)
#
# </div>
#
# ---
#
# ## 🎯 Objetivos de Aprendizaje
#
# Al finalizar esta actividad, serás capaz de:
# - Crear visualizaciones 3D interactivas en Jupyter/Colab con Py3Dmol
# - Utilizar NGLView para visualización avanzada de biomoléculas
# - Trabajar con Avogadro para edición y visualización molecular
# - Usar Chimera UCSF para análisis estructural profesional
# - Dominar PyMOL para imágenes de calidad de publicación
# - Analizar trayectorias de dinámica molecular con VMD
# - Personalizar estilos de representación molecular
# - Generar imágenes y videos de alta calidad
# - Analizar estructuras de proteínas y complejos moleculares
#
# ---
#
# ## 📚 Contenido
#
# 1. [Introducción a la Visualización Molecular](#1-intro)
# 2. [Py3Dmol: Visualización Interactiva en Notebooks](#2-py3dmol)
# 3. [NGLView: Visualización Avanzada](#3-nglview)
# 4. [Avogadro: Editor Molecular](#4-avogadro)
# 5. [Chimera UCSF: Visualización Profesional](#5-chimera)
# 6. [PyMOL: Calidad de Publicación](#6-pymol)
# 7. [VMD: Visual Molecular Dynamics](#7-vmd)
# 8. [Comparación de Herramientas](#8-comparacion)
# 9. [Ejercicios Prácticos](#9-ejercicios)
#
# ---

# %% [markdown]
# ---
#
# ## 📦 Instalación e Importación

# %%
# Instalación en Google Colab
import sys
if 'google.colab' in sys.modules:
    # !pip install py3Dmol -q
    # !pip install rdkit -q
    # !pip install nglview -q
    # !pip install ipywidgets -q
    print("✓ Librerías instaladas")

# %%
# Importar librerías
import numpy as np
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors, Draw
import py3Dmol
import warnings
warnings.filterwarnings('ignore')

print("✓ Librerías importadas correctamente")
print(f"✓ RDKit versión: {Chem.rdBase.rdkitVersion}")

# Verificar NGLView
try:
    import nglview as nv
    print(f"✓ NGLView versión: {nv.__version__}")
except ImportError:
    print("⚠️  NGLView no disponible (requiere instalación local)")

# %% [markdown]
# ---
#
# ## 1. Introducción a la Visualización Molecular <a id="1-intro"></a>
#
# ### 🎨 ¿Por qué Visualizar en 3D?
#
# La visualización tridimensional es fundamental en química computacional porque:
#
# - 🧬 **Comprensión estructural**: Ver la forma real de las moléculas
# - 🔬 **Análisis de interacciones**: Identificar sitios de enlace y cavidades
# - 💊 **Diseño de fármacos**: Evaluar complementariedad molecular
# - 📊 **Comunicación**: Presentar resultados de forma clara
# - 🎓 **Enseñanza**: Facilitar el aprendizaje de conceptos 3D
#
# ### 🛠️ Herramientas de Visualización
#
# | Herramienta | Tipo | Mejor para |
# |-------------|------|------------|
# | **Py3Dmol** | Notebook/Web | Visualización rápida e interactiva |
# | **NGLView** | Notebook | Biomoléculas y trayectorias |
# | **Avogadro** | Desktop | Edición y construcción molecular |
# | **Chimera UCSF** | Desktop | Análisis estructural profesional |
# | **PyMOL** | Desktop | Imágenes de calidad de publicación |
# | **VMD** | Desktop | Trayectorias de dinámica molecular |
#
# ### 📐 Estilos de Representación
#
# - **Stick**: Palos (enlaces como cilindros)
# - **Ball & Stick**: Bolas y palos
# - **Space-filling**: CPK/van der Waals
# - **Cartoon**: Estructura secundaria (proteínas)
# - **Surface**: Superficies moleculares
# - **Ribbon**: Cintas (proteínas)
# - **Licorice**: Palos gruesos (VMD)
#
# ### 🎯 Comparación Rápida
#
# #### Para notebooks (Python):
# - **Py3Dmol**: Moléculas pequeñas, rápido
# - **NGLView**: Proteínas, trayectorias
#
# #### Para desktop (aplicaciones):
# - **Avogadro**: Construir y editar
# - **ChimeraX**: Análisis general
# - **PyMOL**: Figuras para papers
# - **VMD**: Simulaciones MD
#
# ---

# %% [markdown]
# ## 2. Py3Dmol: Visualización Interactiva en Notebooks <a id="2-py3dmol"></a>
#
# **Py3Dmol** es una biblioteca Python que integra 3Dmol.js para crear visualizaciones 3D interactivas directamente en notebooks.
#
# ### ✨ Ventajas
# - ✅ Funciona en Jupyter y Google Colab
# - ✅ Altamente interactivo (rotar, zoom, pan)
# - ✅ Múltiples estilos de visualización
# - ✅ Ligero y rápido
# - ✅ Fácil de usar
#
# ### 🚀 Visualización Básica

# %%
# Crear una molécula simple y visualizarla
mol = Chem.MolFromSmiles("CC(=O)Oc1ccccc1C(=O)O")  # Aspirina

# Generar coordenadas 3D
mol = Chem.AddHs(mol)
AllChem.EmbedMolecule(mol, randomSeed=42)
AllChem.MMFFOptimizeMolecule(mol)

# Convertir a bloque MOL
mol_block = Chem.MolToMolBlock(mol)

# Crear visualización con Py3Dmol
view = py3Dmol.view(width=600, height=400)
view.addModel(mol_block, 'mol')
view.setStyle({'stick': {}})
view.setBackgroundColor('white')
view.zoomTo()
view.show()

# %% [markdown]
# ### 🎨 Diferentes Estilos de Visualización

# %%
# Crear molécula: Cafeína
caffeine = Chem.MolFromSmiles("CN1C=NC2=C1C(=O)N(C(=O)N2C)C")
caffeine = Chem.AddHs(caffeine)
AllChem.EmbedMolecule(caffeine, randomSeed=42)
AllChem.MMFFOptimizeMolecule(caffeine)
caffeine_block = Chem.MolToMolBlock(caffeine)

print("🎨 Estilos de Visualización con Py3Dmol\n")
print("=" * 60)

# Lista de estilos
estilos = [
    ("stick", "Palos (Stick)"),
    ("sphere", "Esferas (Space-filling)"),
    ("line", "Líneas"),
    ("cross", "Cruz"),
]

# Crear visualizaciones lado a lado
for i, (estilo, nombre) in enumerate(estilos):
    print(f"\n{i+1}. {nombre}")
    view = py3Dmol.view(width=400, height=300)
    view.addModel(caffeine_block, 'mol')
    
    if estilo == "stick":
        view.setStyle({estilo: {'radius': 0.15}})
    elif estilo == "sphere":
        view.setStyle({estilo: {'radius': 0.5}})
    else:
        view.setStyle({estilo: {}})
    
    view.setBackgroundColor('white')
    view.zoomTo()
    view.show()

# %% [markdown]
# ### 🌈 Coloreado por Propiedades

# %%
# Colorear átomos por elemento
view = py3Dmol.view(width=600, height=400)
view.addModel(caffeine_block, 'mol')

# Estilo con colores CPK estándar
view.setStyle({'stick': {'colorscheme': 'default'}})
view.setBackgroundColor('#f0f0f0')
view.zoomTo()

print("🌈 Coloreado por tipo de átomo (esquema CPK)\n")
print("   • Carbono: gris")
print("   • Nitrógeno: azul")
print("   • Oxígeno: rojo")
print("   • Hidrógeno: blanco")

view.show()

# %% [markdown]
# ### 🧬 Visualización de Proteínas desde PDB

# %%
# Descargar y visualizar una proteína desde PDB
# Ejemplo: 1UBQ (Ubiquitina)

print("🧬 Visualización de Proteína: Ubiquitina (PDB: 1UBQ)\n")
print("=" * 60)

# Crear visualización desde PDB
view = py3Dmol.view(query='pdb:1UBQ', width=700, height=500)

# Estilo cartoon para estructura secundaria
view.setStyle({'cartoon': {'color': 'spectrum'}})
view.setBackgroundColor('white')
view.zoomTo()

print("\n✓ Estructura cargada desde Protein Data Bank")
print("✓ Estilo: Cartoon (cintas)")
print("✓ Color: Spectrum (arcoíris desde N-terminal a C-terminal)")
print("\n💡 Interacción: Click y arrastra para rotar, scroll para zoom")

view.show()

# %% [markdown]
# ### 🎯 Resaltar Sitios Activos

# %%
# Visualizar proteína con ligando
# Ejemplo: 3HTB (Proteína con inhibidor)

print("🎯 Visualización de Sitio Activo\n")
print("=" * 60)

view = py3Dmol.view(query='pdb:3HTB', width=700, height=500)

# Proteína en cartoon
view.setStyle({'cartoon': {'color': 'lightblue'}})

# Resaltar ligando (heteroátomos)
view.addStyle({'hetflag': True}, {'stick': {'colorscheme': 'greenCarbon', 'radius': 0.3}})

# Mostrar superficie de cavidad
view.addSurface(py3Dmol.VDW, {'opacity': 0.3, 'color': 'white'}, 
                {'hetflag': True})

view.setBackgroundColor('white')
view.zoomTo({'hetflag': True})

print("\n✓ Proteína: cartoon azul claro")
print("✓ Ligando: palos con carbono verde")
print("✓ Superficie: cavidad semitransparente")

view.show()

# %% [markdown]
# ### 🔬 Múltiples Moléculas en una Vista

# %%
# Visualizar múltiples moléculas simultáneamente

# Crear varias moléculas pequeñas
moleculas = {
    "Aspirina": "CC(=O)Oc1ccccc1C(=O)O",
    "Ibuprofeno": "CC(C)Cc1ccc(cc1)C(C)C(=O)O",
    "Paracetamol": "CC(=O)Nc1ccc(cc1)O"
}

print("🔬 Visualización de Múltiples Moléculas\n")
print("=" * 60)

view = py3Dmol.view(width=800, height=400, viewergrid=(1, 3))

for i, (nombre, smiles) in enumerate(moleculas.items()):
    mol = Chem.MolFromSmiles(smiles)
    mol = Chem.AddHs(mol)
    AllChem.EmbedMolecule(mol, randomSeed=42)
    AllChem.MMFFOptimizeMolecule(mol)
    mol_block = Chem.MolToMolBlock(mol)
    
    view.addModel(mol_block, 'mol', viewer=(0, i))
    view.setStyle({'stick': {'colorscheme': 'default'}}, viewer=(0, i))
    view.zoomTo(viewer=(0, i))
    
    print(f"✓ {nombre} cargada en panel {i+1}")

view.setBackgroundColor('white')
print("\n💡 Tres moléculas mostradas lado a lado")
view.show()

# %% [markdown]
# ---
#
# ## 3. NGLView: Visualización Avanzada <a id="3-nglview"></a>
#
# **NGLView** es una biblioteca especializada en visualización de biomoléculas con capacidades avanzadas.
#
# ### ✨ Ventajas de NGLView
# - 🧬 Optimizado para proteínas y ácidos nucleicos
# - 📹 Animación de trayectorias MD
# - 🎨 Múltiples representaciones simultáneas
# - 🔧 Altamente personalizable
# - 📊 Integración con MDAnalysis y MDTraj
#
# ### 🚀 Uso Básico de NGLView

# %%
# NGLView requiere instalación local y puede no funcionar en Colab
# Este código funcionará en Jupyter Notebook local

try:
    import nglview as nv
    
    # Crear molécula
    mol = Chem.MolFromSmiles("CN1C=NC2=C1C(=O)N(C(=O)N2C)C")
    mol = Chem.AddHs(mol)
    AllChem.EmbedMolecule(mol, randomSeed=42)
    AllChem.MMFFOptimizeMolecule(mol)
    
    # Guardar temporalmente
    writer = Chem.SDWriter('temp_mol.sdf')
    writer.write(mol)
    writer.close()
    
    # Visualizar con NGLView
    view = nv.show_file('temp_mol.sdf')
    view.add_representation('ball+stick')
    
    print("✓ Molécula visualizada con NGLView")
    display(view)
    
except ImportError:
    print("⚠️  NGLView requiere instalación local")
    print("\n📦 Para instalar:")
    print("   conda install -c conda-forge nglview")
    print("   jupyter nbextension enable nglview --py --sys-prefix")
    print("\n💡 NGLView funciona mejor en Jupyter Notebook local")
    print("   Para Google Colab, usa Py3Dmol en su lugar")
except Exception as e:
    print(f"⚠️  Error: {e}")
    print("💡 NGLView puede no estar disponible en este entorno")

# %% [markdown]
# ### 🧬 Visualización de Proteínas con NGLView

# %%
# Ejemplo de visualización de proteína (requiere NGLView instalado)

try:
    import nglview as nv
    
    # Cargar estructura desde PDB
    view = nv.show_pdbid("1UBQ")  # Ubiquitina
    
    # Limpiar representaciones por defecto
    view.clear_representations()
    
    # Agregar múltiples representaciones
    view.add_representation('cartoon', selection='protein', color='residueindex')
    view.add_representation('ball+stick', selection='hetero')
    view.add_representation('surface', selection='protein', opacity=0.3)
    
    # Centrar
    view.center()
    
    print("✓ Proteína 1UBQ cargada con múltiples representaciones:")
    print("   • Cartoon: estructura secundaria")
    print("   • Ball+stick: ligandos")
    print("   • Surface: superficie molecular")
    
    display(view)
    
except:
    print("⚠️  Esta visualización requiere NGLView en Jupyter local")
    print("💡 Alternativa: Usa Py3Dmol (mostrado anteriormente)")

# %% [markdown]
# ---
#
# ## 4. Avogadro: Editor Molecular <a id="4-avogadro"></a>
#
# **Avogadro** es un editor y visualizador molecular avanzado, gratuito y de código abierto.
#
# ### 🎯 Características Principales
#
# - 🔧 **Editor molecular**: Construir moléculas desde cero
# - ⚛️ **Optimización de geometría**: Campos de fuerza integrados
# - 🎨 **Visualización avanzada**: Múltiples estilos y propiedades
# - 📊 **Propiedades calculadas**: Descriptores y análisis
# - 🔌 **Plugins**: Extensible con complementos
# - 📁 **Formatos**: Soporta >90 formatos químicos
#
# ### 💻 Instalación
#
# #### Windows:
# ```bash
# # Descargar desde: https://avogadro.cc/
# # Instalar el archivo .exe
# ```
#
# #### Linux (Ubuntu/Debian):
# ```bash
# sudo apt-get update
# sudo apt-get install avogadro
# ```
#
# #### macOS:
# ```bash
# brew install --cask avogadro
# ```
#
# ### 📚 Guía de Uso de Avogadro
#
# #### 1️⃣ Construir una Molécula
#
# 1. Abrir Avogadro
# 2. Herramientas → Build → Seleccionar elemento (C, H, O, N, etc.)
# 3. Click en el espacio vacío para crear átomos
# 4. Click entre átomos para crear enlaces
# 5. Click derecho → Ajustar tipo de enlace
#
# #### 2️⃣ Optimizar Geometría
#
# 1. Extensions → Optimize Geometry
# 2. Seleccionar campo de fuerza (UFF, MMFF94, Ghemical)
# 3. Click "Optimize"
# 4. Ver energía resultante
#
# #### 3️⃣ Visualizar Propiedades
#
# 1. View → Properties
# 2. Seleccionar:
#    - Display Settings: Estilo de visualización
#    - Molecule Properties: Peso molecular, fórmula
#    - Atom Properties: Cargas parciales
#
# #### 4️⃣ Guardar y Exportar
#
# 1. File → Save As
# 2. Seleccionar formato:
#    - `.xyz`: Coordenadas cartesianas
#    - `.pdb`: Protein Data Bank
#    - `.mol` / `.sdf`: MDL Molfile
#    - `.cml`: Chemical Markup Language
#
# ### 🎨 Estilos de Visualización en Avogadro
#
# - **Ball and Stick**: Por defecto, ideal para ver geometría
# - **Van der Waals Spheres**: Tamaño real de átomos
# - **Stick**: Solo enlaces
# - **Wireframe**: Modelo de alambre
# - **Cartoon**: Para proteínas
#
# ### 📝 Ejemplo Práctico: Crear Cafeína
#
# Sigue estos pasos en Avogadro:

# %% [markdown]
# ```
# Paso 1: Crear el esqueleto
# 1. Seleccionar carbono (C)
# 2. Construir dos anillos fusionados (5 y 6 miembros)
# 3. Agregar nitrógenos en posiciones correctas
#
# Paso 2: Agregar grupos funcionales
# 1. Agregar grupos metilo (CH₃)
# 2. Agregar grupos carbonilo (C=O)
#
# Paso 3: Optimizar
# 1. Extensions → Optimize Geometry
# 2. Seleccionar MMFF94
# 3. Optimizar
#
# Paso 4: Verificar
# 1. Display → Properties → Peso molecular (194.19 g/mol)
# 2. Guardar como cafeina.xyz
# ```
#
# ### 🔬 Análisis de Propiedades en Avogadro
#
# Avogadro puede calcular:
# - **Peso molecular**
# - **Fórmula molecular**
# - **Momento dipolar**
# - **Cargas parciales** (Gasteiger, MMFF94)
# - **Volumen y área superficial**
# - **Ángulos y distancias**
#
# ### 💡 Consejos para Usar Avogadro
#
# ✅ **Hacer frecuentemente**:
# - Optimizar geometría después de construir
# - Usar auto-optimización durante construcción
# - Verificar hibridación de átomos
# - Guardar versiones intermedias
#
# ❌ **Evitar**:
# - Construir estructuras muy grandes (>500 átomos)
# - Olvidar agregar hidrógenos
# - No optimizar antes de guardar

# %% [markdown]
# ---
#
# ## 5. Chimera UCSF: Visualización Profesional <a id="5-chimera"></a>
#
# **UCSF Chimera** (y su sucesor **ChimeraX**) son herramientas profesionales para visualización y análisis molecular.
#
# ### 🎯 Características Principales
#
# - 🧬 **Especializado en biomoléculas**: Proteínas, ácidos nucleicos
# - 🔬 **Análisis estructural**: Cavidades, superficies, volúmenes
# - 🎨 **Calidad de publicación**: Imágenes de alta resolución
# - 📊 **Análisis cuantitativo**: Distancias, ángulos, RMSD
# - 🔌 **Scripting**: Python API completa
# - 📹 **Animaciones**: Crear videos de rotación
#
# ### 💻 Instalación
#
# #### Todas las plataformas:
# - **Chimera (clásico)**: https://www.cgl.ucsf.edu/chimera/
# - **ChimeraX (nuevo)**: https://www.rbvi.ucsf.edu/chimerax/
#
# Ambos son **gratuitos para uso académico**.
#
# ### 📚 Guía de Uso de ChimeraX
#
# #### 1️⃣ Abrir una Estructura
#
# ```
# # Desde archivo
# File → Open → Seleccionar archivo PDB/CIF
#
# # Desde PDB
# File → Fetch by ID → Ingresar código (ej: 1UBQ)
#
# # Desde comando
# Command: open 1ubq
# ```
#
# #### 2️⃣ Estilos de Visualización
#
# ```bash
# # Comandos básicos de ChimeraX
#
# # Cartoon (cintas)
# cartoon
#
# # Átomos
# show atoms
# hide atoms
#
# # Superficie
# surface
# ~surface  # ocultar
#
# # Colores
# color bychain
# color byhetero
# color byfactor
# ```
#
# #### 3️⃣ Selecciones
#
# ```bash
# # Seleccionar residuos
# select :1-10      # Residuos 1 al 10
# select :ALA       # Todas las alaninas
# select ligand     # Ligandos
#
# # Seleccionar cadenas
# select /A         # Cadena A
#
# # Por proximidad
# select :50 < 5    # Dentro de 5 Å del residuo 50
# ```
#
# #### 4️⃣ Mediciones
#
# ```bash
# # Distancias
# distance #1:45@CA #1:60@CA
#
# # Ángulos
# angle #1:10@CA #1:20@CA #1:30@CA
#
# # Área superficial
# measure sasa #1
# ```
#
# ### 🎨 Visualizaciones Comunes en ChimeraX
#
# #### Proteína con Ligando
# ```bash
# open 3htb
# cartoon
# color bychain
# select ligand
# show ligand atoms
# style ligand stick
# color ligand byhetero
# surface ligand
# transparency 70
# ```
#
# #### Análisis de Cavidades
# ```bash
# open 1ubq
# surface
# color surface byhydrophobicity
# measure buriedarea #1
# ```
#
# #### Comparación de Estructuras
# ```bash
# open 1ubq
# open 1ubi
# matchmaker #1 to #2
# rmsd #1 to #2
# ```
#
# ### 📸 Generar Imágenes de Calidad
#
# ```bash
# # Configurar vista
# set bgColor white
# lighting soft
# graphics silhouettes true
#
# # Guardar imagen
# save ~/proteina.png width 3000 height 2000 supersample 3
# ```
#
# ### 🎬 Crear Animaciones
#
# ```bash
# # Rotación 360°
# turn y 1 360
#
# # Guardar video
# movie record
# turn y 2 180
# wait
# movie encode ~/rotacion.mp4
# ```
#
# ### 💡 Comandos Útiles de ChimeraX
#
# | Comando | Función |
# |---------|---------|
# | `open 1ubq` | Abrir estructura desde PDB |
# | `cartoon` | Mostrar estructura secundaria |
# | `surface` | Mostrar superficie molecular |
# | `color bychain` | Colorear por cadena |
# | `select ligand` | Seleccionar ligandos |
# | `measure buriedarea` | Calcular área enterrada |
# | `rmsd` | Calcular desviación RMSD |
# | `save imagen.png` | Guardar imagen |
#
# ### 🔬 Casos de Uso Avanzados
#
# #### 1. Análisis de Interfaces Proteína-Proteína
# ```bash
# open 2hhb  # Hemoglobina
# contacts #1/A with #1/B
# measure buriedarea #1/A with #1/B
# ```
#
# #### 2. Visualización de Electrostática
# ```bash
# open 1ubq
# coulombic
# color byelectrostatics
# ```
#
# #### 3. Comparación Estructural
# ```bash
# open 1ubq
# open 1ubi
# matchmaker #1 to #2
# morph #1,2 frames 50
# movie record
# morph start
# wait 50
# movie encode morph.mp4
# ```

# %% [markdown]
# ---
#
# ## 6. PyMOL: Visualización de Calidad Profesional <a id="6-pymol"></a>
#
# **PyMOL** es una de las herramientas más populares para visualización molecular, especialmente en investigación biomédica y estructural.
#
# ### 🎯 Características Principales
#
# - 🎨 **Calidad de publicación**: Renderizado de alta calidad
# - 🧬 **Especializado en proteínas**: Estructuras secundarias, superficies
# - 📊 **Ray tracing**: Imágenes fotorrealistas
# - 🔧 **Altamente personalizable**: Control total sobre la visualización
# - 🐍 **API Python**: Scripting completo
# - 🎬 **Animaciones**: Crear videos profesionales
#
# ### 💻 Instalación
#
# #### Versión Open-Source (Gratuita):
# ```bash
# # Con conda (recomendado)
# conda install -c conda-forge pymol-open-source
#
# # En Ubuntu/Debian
# sudo apt-get install pymol
# ```
#
# #### Versión Comercial:
# - **PyMOL Educational**: Gratuita para uso educativo
# - **PyMOL Commercial**: Licencia comercial
# - Descarga: https://pymol.org/
#
# ### 📚 Guía de Uso de PyMOL
#
# #### 1️⃣ Interfaz Básica
#
# PyMOL tiene dos ventanas principales:
# - **Viewer**: Ventana 3D de visualización
# - **Command Line**: Línea de comandos
#
# #### 2️⃣ Comandos Básicos
#
# ```python
# # Cargar estructura
# fetch 1ubq              # Desde PDB
# load proteina.pdb       # Desde archivo
#
# # Visualización
# show cartoon           # Mostrar estructura secundaria
# show sticks            # Mostrar átomos como palos
# show spheres           # Mostrar esferas
# show surface           # Mostrar superficie
#
# # Ocultar
# hide everything
# hide lines
#
# # Colores
# color red, chain A
# color blue, chain B
# color cyan, resi 10-20
# util.cbc                # Color by chain (rainbow)
#
# # Selecciones
# select activo, resi 50 around 5    # 5 Å alrededor del residuo 50
# select ligando, organic
#
# # Alineamiento
# align proteina1, proteina2
# super proteina1, proteina2         # Superposición
# ```
#
# #### 3️⃣ Representaciones Comunes
#
# ```python
# # Proteína estilo cartoon
# hide everything
# show cartoon
# color cyan, ss h        # Hélices en cyan
# color magenta, ss s     # Láminas en magenta
# color orange, ss l      # Loops en naranja
#
# # Sitio activo
# select sitio, resi 10+15+20+45
# show sticks, sitio
# color green, sitio
# show spheres, sitio and name CA
#
# # Superficie molecular
# show surface
# set transparency, 0.5
# ```
#
# #### 4️⃣ Personalización Avanzada
#
# ```python
# # Configuración visual
# bg_color white                    # Fondo blanco
# set depth_cue, 0                  # Sin oscurecimiento por profundidad
# set ray_shadows, 1                # Activar sombras
# set antialias, 2                  # Anti-aliasing
# set ambient, 0.3                  # Luz ambiente
# set specular, 1                   # Luz especular
#
# # Mejorar apariencia
# set cartoon_fancy_helices, 1      # Hélices con caras planas
# set cartoon_smooth_loops, 1       # Loops suavizados
# set stick_radius, 0.15            # Grosor de palos
# ```
#
# #### 5️⃣ Generar Imágenes de Alta Calidad
#
# ```python
# # Preparar vista
# orient
# zoom
# bg_color white
#
# # Configurar renderizado
# set ray_trace_mode, 1
# set ray_shadows, 1
# set antialias, 2
#
# # Guardar imagen
# ray 3000, 2000                    # Renderizar 3000x2000 px
# png figura_proteina.png, dpi=300  # Guardar con 300 DPI
# ```
#
# ### 🎨 Ejemplos Prácticos con PyMOL
#
# #### Ejemplo 1: Visualizar Ubiquitina
# ```python
# # Cargar estructura
# fetch 1ubq
#
# # Configurar visualización
# hide everything
# show cartoon
# color cyan
# bg_color white
#
# # Resaltar residuos clave
# select key_residues, resi 10+25+40
# show sticks, key_residues
# color orange, key_residues
#
# # Vista bonita
# set cartoon_fancy_helices, 1
# orient
# zoom
# ```
#
# #### Ejemplo 2: Comparar Dos Estructuras
# ```python
# # Cargar dos estructuras
# fetch 1ubq, structure1
# fetch 1ubi, structure2
#
# # Alinear
# align structure2, structure1
#
# # Colorear diferente
# color cyan, structure1
# color magenta, structure2
#
# # Calcular RMSD
# rms structure1, structure2
# # Resultado se muestra en consola
# ```
#
# #### Ejemplo 3: Sitio Activo con Ligando
# ```python
# # Cargar estructura con ligando
# fetch 3htb
#
# # Proteína en cartoon
# hide everything
# show cartoon
# color lightblue
#
# # Mostrar ligando
# select ligando, organic
# show sticks, ligando
# color green, ligando and elem C
# util.cbag ligando    # Color by atom (verde)
#
# # Residuos cercanos
# select pocket, byres ligando around 5
# show lines, pocket
# color yellow, pocket
#
# # Superficie de cavidad
# show surface, pocket
# set transparency, 0.7
# ```
#
# #### Ejemplo 4: Colorear por B-factor
# ```python
# # Cargar estructura
# fetch 1ubq
#
# # Visualizar
# hide everything
# show cartoon
# spectrum b, blue_white_red
# bg_color white
#
# # Barra de color
# ramp_new b_ramp, 1ubq, b, [10, 30, 50]
# ```
#
# ### 💡 Scripting con PyMOL en Python
#
# PyMOL puede ser controlado desde Python:
#
# ```python
# import pymol
# from pymol import cmd
#
# # Iniciar PyMOL
# pymol.finish_launching()
#
# # Comandos
# cmd.fetch("1ubq")
# cmd.hide("everything")
# cmd.show("cartoon")
# cmd.color("cyan")
#
# # Exportar imagen
# cmd.bg_color("white")
# cmd.ray(1920, 1080)
# cmd.png("output.png", dpi=300)
#
# # Guardar sesión
# cmd.save("sesion.pse")
# ```
#
# ### 🎬 Crear Animaciones
#
# ```python
# # Configurar escena
# fetch 1ubq
# hide everything
# show cartoon
# color cyan
# bg_color white
#
# # Animación de rotación
# mset 1 x120              # 120 frames
# util.mroll(1, 120, 1)    # Rotar eje Y
#
# # Exportar frames
# mpng frame_              # Guarda frame_0001.png, frame_0002.png, etc.
#
# # Crear video con ffmpeg:
# # ffmpeg -r 30 -i frame_%04d.png -c:v libx264 -pix_fmt yuv420p video.mp4
# ```
#
# ### 📊 Casos de Uso Avanzados
#
# #### 1. Superficie Electrostática
# ```python
# # Requiere plugin APBS
# # Cargar estructura
# fetch 1ubq
#
# # Generar superficie electrostática
# util.protein_vacuum_esp("1ubq", mode=2, quiet=0)
#
# # Visualizar
# hide everything
# show surface
# ramp_new e_lvl, 1ubq, e_pot, [-10, 0, 10]
# set surface_color, e_lvl
# ```
#
# #### 2. Visualizar Cavidades
# ```python
# # Cargar estructura
# fetch 1ubq
#
# # Detectar cavidades
# select pockets, within 2.5 of (resi 10+20+30)
# show surface, pockets
# set transparency, 0.3
# ```
#
# #### 3. Distancias y Ángulos
# ```python
# # Medir distancia
# distance d1, /1ubq//A/10/CA, /1ubq//A/20/CA
#
# # Medir ángulo
# angle a1, /1ubq//A/10/CA, /1ubq//A/20/CA, /1ubq//A/30/CA
#
# # Personalizar medidas
# set dash_color, yellow
# set dash_width, 3
# ```
#
# ### 💡 Consejos para PyMOL
#
# ✅ **Mejores prácticas**:
# - Usar `bg_color white` para publicaciones
# - Activar `ray_shadows` para renderizado final
# - Guardar sesiones (`.pse`) para volver a trabajar
# - Usar `orient` y `zoom` antes de guardar imágenes
# - Aumentar `ray_trace_mode` para mejor calidad
#
# ❌ **Evitar**:
# - No usar colores fosforescentes para publicaciones
# - No renderizar imágenes de baja resolución
# - No olvidar optimizar la vista antes de ray tracing
#
# ---

# %% [markdown]
# ---
#
# ## 7. VMD: Visual Molecular Dynamics <a id="7-vmd"></a>
#
# **VMD (Visual Molecular Dynamics)** es una herramienta especializada en visualización y análisis de trayectorias de dinámica molecular.
#
# ### 🎯 Características Principales
#
# - 📹 **Trayectorias MD**: Reproducir simulaciones de dinámica molecular
# - 🧬 **Biomoléculas grandes**: Optimizado para sistemas complejos
# - 📊 **Análisis integrado**: RMSD, RMSF, distancias, ángulos
# - 🎨 **Múltiples representaciones**: Simultáneas y combinables
# - 🔧 **Scripting Tcl/Python**: Automatización completa
# - 🎬 **Rendering avanzado**: Tachyon, POV-Ray
#
# ### 💻 Instalación
#
# #### Todas las plataformas:
# - **Descarga gratuita**: https://www.ks.uiuc.edu/Research/vmd/
# - Disponible para Windows, Linux, macOS
# - Requiere registro (gratuito)
#
# #### Linux (Ubuntu/Debian):
# ```bash
# # Descargar desde web oficial
# chmod +x vmd-*.bin
# sudo ./vmd-*.bin
# ```
#
# ### 📚 Guía de Uso de VMD
#
# #### 1️⃣ Interfaz Principal
#
# VMD tiene tres ventanas:
# - **OpenGL Display**: Ventana de visualización 3D
# - **VMD Main**: Control principal y menús
# - **Tk Console**: Consola de comandos Tcl
#
# #### 2️⃣ Cargar Estructuras
#
# ```tcl
# # Desde interfaz:
# File → New Molecule → Browse → Load
#
# # Desde consola Tcl:
# mol new proteina.pdb
# mol new sistema.psf
#
# # Cargar trayectoria
# mol addfile trayectoria.dcd waitfor all
# ```
#
# #### 3️⃣ Representaciones Básicas
#
# ```tcl
# # Crear representaciones
# Graphics → Representations
#
# # Selecciones comunes:
# all                    # Todo
# protein                # Solo proteína
# water                  # Moléculas de agua
# resname LIG           # Residuo llamado LIG
# resid 10 to 50        # Residuos 10 al 50
# within 5 of resid 25  # Dentro de 5 Å del residuo 25
#
# # Estilos de dibujo:
# Lines                  # Líneas
# Bonds                  # Enlaces
# DynamicBonds          # Enlaces dinámicos
# Licorice              # Palos gruesos
# CPK                   # Esferas CPK
# VDW                   # Van der Waals
# Cartoon               # Estructura secundaria
# NewCartoon            # Cartoon mejorado
# Surf                  # Superficie
# QuickSurf             # Superficie rápida
# ```
#
# #### 4️⃣ Comandos Comunes de Consola
#
# ```tcl
# # Selección de átomos
# set sel [atomselect top "protein"]
# $sel num                           # Número de átomos
# $sel get {x y z}                   # Coordenadas
# $sel get resname                   # Nombres de residuos
#
# # Centro de masa
# measure center $sel
# measure center $sel weight mass
#
# # RMSD
# set ref [atomselect 0 "protein and backbone"]
# set comp [atomselect 1 "protein and backbone"]
# measure rmsd $comp $ref
#
# # Giroid (radio de giro)
# measure rgyr $sel
#
# # SASA (área superficial accesible)
# measure sasa 1.4 $sel
#
# # Distancia
# set atom1 [atomselect top "protein and resid 10 and name CA"]
# set atom2 [atomselect top "protein and resid 20 and name CA"]
# vecdist [lindex [$atom1 get {x y z}] 0] [lindex [$atom2 get {x y z}] 0]
# ```
#
# ### 🎨 Ejemplos Prácticos con VMD
#
# #### Ejemplo 1: Visualizar Proteína Básica
# ```tcl
# # Cargar estructura
# mol new 1ubq.pdb
#
# # Configurar representación
# mol delrep 0 top
# mol representation NewCartoon
# mol color Structure
# mol selection protein
# mol material Opaque
# mol addrep top
#
# # Agregar representación de superficie
# mol representation QuickSurf
# mol color ColorID 7
# mol selection protein
# mol material Transparent
# mol addrep top
# ```
#
# #### Ejemplo 2: Analizar Trayectoria MD
# ```tcl
# # Cargar topología y trayectoria
# mol new sistema.psf
# mol addfile trayectoria.dcd waitfor all
#
# # Visualizar proteína
# mol representation NewCartoon
# mol color Chain
# mol selection "protein"
# mol addrep top
#
# # Visualizar ligando
# mol representation Licorice
# mol color Name
# mol selection "resname LIG"
# mol addrep top
#
# # Reproducir trayectoria
# animate goto 0
# animate forward
# ```
#
# #### Ejemplo 3: Calcular RMSD vs Tiempo
# ```tcl
# # Script para calcular RMSD
# set outfile [open rmsd.dat w]
# set nframes [molinfo top get numframes]
# set reference [atomselect top "protein and backbone" frame 0]
#
# for {set frame 0} {$frame < $nframes} {incr frame} {
#     set compare [atomselect top "protein and backbone" frame $frame]
#     $compare move [measure fit $compare $reference]
#     set rmsd [measure rmsd $compare $reference]
#     puts $outfile "$frame $rmsd"
#     $compare delete
# }
#
# close $outfile
# $reference delete
#
# puts "RMSD guardado en rmsd.dat"
# ```
#
# #### Ejemplo 4: Visualizar Canal de Agua
# ```tcl
# # Cargar sistema con agua
# mol new sistema.pdb
#
# # Proteína en cartoon
# mol representation NewCartoon
# mol color Chain
# mol selection "protein"
# mol addrep top
#
# # Agua en el canal
# mol representation VDW
# mol color Name
# mol selection "water and within 3 of (protein and resid 50 60 70)"
# mol addrep top
# ```
#
# ### 📊 Análisis Comunes en VMD
#
# #### 1. RMSF (Fluctuaciones)
# ```tcl
# # RMSF por residuo
# set sel [atomselect top "protein and name CA"]
# set nframes [molinfo top get numframes]
#
# set rmsf {}
# for {set i 0} {$i < [$sel num]} {incr i} {
#     set atom [atomselect top "protein and name CA and index $i"]
#     set coords {}
#     for {set frame 0} {$frame < $nframes} {incr frame} {
#         $atom frame $frame
#         lappend coords [lindex [$atom get {x y z}] 0]
#     }
#     # Calcular fluctuación
#     set avg [vecmean $coords]
#     set sq_dev 0
#     foreach coord $coords {
#         set sq_dev [expr $sq_dev + [veclength2 [vecsub $coord $avg]]]
#     }
#     lappend rmsf [expr sqrt($sq_dev / $nframes)]
#     $atom delete
# }
#
# # Guardar RMSF
# set outfile [open rmsf.dat w]
# for {set i 0} {$i < [llength $rmsf]} {incr i} {
#     puts $outfile "$i [lindex $rmsf $i]"
# }
# close $outfile
# ```
#
# #### 2. Enlaces de Hidrógeno
# ```tcl
# # Contar enlaces de hidrógeno
# package require hbonds
#
# # Entre proteína y ligando
# hbonds -sel1 [atomselect top "protein"] \
#        -sel2 [atomselect top "resname LIG"] \
#        -dist 3.0 \
#        -ang 20 \
#        -writefile hbonds.dat
# ```
#
# #### 3. Contactos Nativos
# ```tcl
# # Identificar contactos nativos (< 4.5 Å)
# set sel1 [atomselect top "protein and resid 1 to 50"]
# set sel2 [atomselect top "protein and resid 51 to 100"]
#
# set contacts [measure contacts 4.5 $sel1 $sel2]
# set num_contacts [llength [lindex $contacts 0]]
#
# puts "Número de contactos: $num_contacts"
# ```
#
# ### 🎬 Crear Visualizaciones y Videos
#
# #### Renderizado de Alta Calidad
# ```tcl
# # Configurar vista
# display projection Orthographic
# display depthcue off
# display rendermode GLSL
# axes location Off
# color Display Background white
#
# # Renderizar con Tachyon
# render Tachyon imagen.dat "/usr/local/lib/vmd/tachyon_LINUX" -aasamples 12 %s -format TARGA -o %s.tga
#
# # O con POV-Ray (mejor calidad)
# render POVRay imagen.pov povray +W1920 +H1080 +A0.3
# ```
#
# #### Crear Animación
# ```tcl
# # Configurar para video
# display projection Orthographic
# color Display Background white
#
# # Renderizar cada frame
# set nframes [molinfo top get numframes]
# for {set i 0} {$i < $nframes} {incr i} {
#     animate goto $i
#     render snapshot frame.[format "%04d" $i].tga
# }
#
# # Crear video con mencoder:
# # mencoder "mf://frame.*.tga" -mf fps=30 -o video.avi -ovc lavc
# ```
#
# ### 🔧 Plugins Útiles de VMD
#
# | Plugin | Función |
# |--------|---------|
# | **Timeline** | Ver evolución temporal de estructuras |
# | **RMSD Trajectory Tool** | Calcular RMSD gráficamente |
# | **Salt Bridges** | Identificar puentes salinos |
# | **Hydrogen Bonds** | Analizar enlaces de hidrógeno |
# | **CAVER** | Detectar canales y cavidades |
# | **HOLE** | Analizar poros transmembrana |
# | **MultiSeq** | Alineamiento de secuencias |
#
# ### 💡 Scripting con VMD en Python
#
# VMD también soporta Python (mediante VMD-Python):
#
# ```python
# # Cargar en Python
# from VMD import molecule, atomsel, render
#
# # Cargar molécula
# mol = molecule.load('pdb', '1ubq.pdb')
#
# # Selección
# sel = atomsel('protein', mol)
# print(f"Número de átomos: {sel.num()}")
#
# # Centro de masa
# com = sel.center()
# print(f"Centro de masa: {com}")
#
# # Renderizar
# render('snapshot', 'imagen.tga')
# ```
#
# ### 💡 Consejos para VMD
#
# ✅ **Mejores prácticas**:
# - Usar QuickSurf en lugar de Surf para sistemas grandes
# - Activar "Update Selection Every Frame" para trayectorias
# - Guardar estado (File → Save State)
# - Usar scripts para análisis reproducibles
# - Aprovechar plugins especializados
#
# ❌ **Evitar**:
# - No cargar trayectorias muy largas sin analizar necesidad
# - No usar VDW para sistemas muy grandes (lento)
# - No olvidar alinear frames antes de calcular RMSD
#
# ### 🔬 Casos de Uso Típicos
#
# 1. **Análisis de estabilidad**: RMSD, RMSF, Rgyr
# 2. **Interacciones**: Enlaces H, puentes salinos, contactos
# 3. **Conformaciones**: PCA, clustering de estructuras
# 4. **Solvatación**: Análisis de agua, número de coordinación
# 5. **Canales**: Identificación y caracterización de poros
#
# ---

# %% [markdown]
# ---
#
# ## 8. Comparación de Herramientas <a id="8-comparacion"></a>
#
# ### 📊 Tabla Comparativa Completa
#
# | Característica | Py3Dmol | NGLView | Avogadro | ChimeraX | PyMOL | VMD |
# |----------------|---------|---------|----------|----------|-------|-----|
# | **Tipo** | Web/Notebook | Notebook | Desktop | Desktop | Desktop | Desktop |
# | **Interactividad** | Alta | Alta | Alta | Muy Alta | Muy Alta | Muy Alta |
# | **Moléculas pequeñas** | ⭐⭐⭐⭐⭐ | ⭐⭐⭐ | ⭐⭐⭐⭐⭐ | ⭐⭐⭐⭐ | ⭐⭐⭐⭐ | ⭐⭐⭐ |
# | **Proteínas** | ⭐⭐⭐⭐ | ⭐⭐⭐⭐⭐ | ⭐⭐⭐ | ⭐⭐⭐⭐⭐ | ⭐⭐⭐⭐⭐ | ⭐⭐⭐⭐⭐ |
# | **Trayectorias MD** | ❌ | ⭐⭐⭐⭐ | ❌ | ⭐⭐⭐ | ⭐⭐ | ⭐⭐⭐⭐⭐ |
# | **Edición** | ❌ | ❌ | ✅ | ✅ | ❌ | ❌ |
# | **Análisis** | Básico | Medio | Medio | Avanzado | Avanzado | Muy Avanzado |
# | **Calidad imagen** | Media | Media | Alta | Muy Alta | Muy Alta | Muy Alta |
# | **Ray tracing** | ❌ | ❌ | ❌ | ✅ | ✅ | ✅ |
# | **Curva aprendizaje** | Baja | Baja | Media | Alta | Media-Alta | Alta |
# | **Scripting** | Python | Python | Plugin | Python | Python | Tcl/Python |
# | **Precio** | Gratis | Gratis | Gratis | Gratis | OSS/Edu/Com | Gratis |
# | **Mejor para** | Notebooks | Biomol/Traj | Construcción | Investigación | Publicaciones | Traj MD |
#
# ### 🎯 ¿Cuál Usar?
#
# #### Use **Py3Dmol** cuando:
# - ✅ Trabaje en notebooks (Jupyter/Colab)
# - ✅ Necesite visualización rápida e interactiva
# - ✅ Quiera compartir visualizaciones online
# - ✅ Visualice moléculas pequeñas o medianas
# - ✅ No requiera análisis detallado
#
# #### Use **NGLView** cuando:
# - ✅ Analice biomoléculas en notebooks
# - ✅ Tenga trayectorias de dinámica molecular
# - ✅ Necesite múltiples representaciones simultáneas
# - ✅ Trabaje en Jupyter local
# - ✅ Integre con MDAnalysis/MDTraj
#
# #### Use **Avogadro** cuando:
# - ✅ Construya moléculas desde cero
# - ✅ Necesite optimizar geometrías localmente
# - ✅ Edite estructuras moleculares
# - ✅ Prepare inputs para cálculos cuánticos
# - ✅ Enseñe química molecular básica
#
# #### Use **ChimeraX** cuando:
# - ✅ Analice proteínas y estructuras complejas
# - ✅ Necesite imágenes de calidad de publicación
# - ✅ Compare múltiples estructuras (RMSD)
# - ✅ Realice análisis cuantitativo detallado
# - ✅ Explore cavidades y superficies
#
# #### Use **PyMOL** cuando:
# - ✅ Genere figuras para publicaciones científicas
# - ✅ Necesite control fino sobre la visualización
# - ✅ Cree presentaciones profesionales
# - ✅ Requiera ray tracing de alta calidad
# - ✅ Trabaje con estructuras cristalográficas
# - ✅ Script visualizaciones complejas
#
# #### Use **VMD** cuando:
# - ✅ Analice trayectorias de dinámica molecular
# - ✅ Calcule RMSD, RMSF, propiedades dinámicas
# - ✅ Visualice sistemas muy grandes (>100k átomos)
# - ✅ Necesite plugins especializados (HOLE, CAVER)
# - ✅ Trabaje con simulaciones de NAMD, GROMACS, AMBER
# - ✅ Realice análisis de membrana/solvente
#
# ### 💡 Flujo de Trabajo Típico
#
# ```
# 1. Construcción inicial     → Avogadro
# 2. Optimización             → Avogadro / Cálculos externos
# 3. Visualización rápida     → Py3Dmol (notebook)
# 4. Simulación MD            → GROMACS / NAMD / AMBER
# 5. Análisis trayectoria     → VMD
# 6. Análisis estructural     → ChimeraX / PyMOL
# 7. Figuras publicación      → PyMOL / ChimeraX
# 8. Presentación interactiva → Py3Dmol / NGLView
# ```
#
# ### 🔄 Interoperabilidad
#
# Las herramientas se complementan:
#
# ```
# Avogadro → .pdb → PyMOL/ChimeraX/VMD
# RDKit → Py3Dmol (visualización en notebook)
# MD Simulation → VMD (análisis) → PyMOL (figuras)
# PDB → cualquier herramienta
# ChimeraX → sesiones → PyMOL
# ```
#
# ### 📈 Recomendaciones por Nivel
#
# #### Principiante:
# 1. **Py3Dmol** - Fácil, en notebooks
# 2. **Avogadro** - Interface gráfica intuitiva
# 3. **ChimeraX** - Documentación excelente
#
# #### Intermedio:
# 1. **PyMOL** - Balance poder/facilidad
# 2. **NGLView** - Para trayectorias
# 3. **ChimeraX** - Análisis avanzado
#
# #### Avanzado:
# 1. **VMD** - Control total sobre trayectorias
# 2. **PyMOL scripting** - Automatización
# 3. **ChimeraX Python API** - Análisis personalizado
#
# ### 🎓 Recursos de Aprendizaje
#
# | Herramienta | Tutorial Recomendado |
# |-------------|---------------------|
# | **Py3Dmol** | http://3dmol.csb.pitt.edu/doc/ |
# | **NGLView** | http://nglviewer.org/nglview/latest/ |
# | **Avogadro** | https://avogadro.cc/docs/ |
# | **ChimeraX** | https://www.rbvi.ucsf.edu/chimerax/docs/user/index.html |
# | **PyMOL** | https://pymolwiki.org/ |
# | **VMD** | https://www.ks.uiuc.edu/Research/vmd/current/ug/ |
#
# ---

# %%
---

## 9. Ejercicios Prácticos <a id="9-ejercicios"></a>

### 📝 Ejercicio 1: Galería de Moléculas con Py3Dmol

Crea una galería interactiva de fármacos comunes:

# %% [markdown]
# ### 📝 Ejercicio 2: Visualización de Proteína
#
# Descarga y visualiza una proteína de interés:

# %%
# Ejercicio 2: Análisis de proteína

# Selecciona un código PDB de tu interés, por ejemplo:
# - 1UBQ: Ubiquitina (pequeña)
# - 2HHB: Hemoglobina
# - 3HTB: Proteína con inhibidor
# - 6M0J: Proteasa de SARS-CoV-2

pdb_code = "1UBQ"  # Cambia por el que quieras

# TU CÓDIGO AQUÍ
# 1. Carga la estructura con Py3Dmol
# 2. Muestra la estructura secundaria (cartoon)
# 3. Si hay ligandos, resáltalos
# 4. Agrega una superficie semitransparente
# 5. Colorea por estructura secundaria

# %% [markdown]
# ### 📝 Ejercicio 3: Tareas con Avogadro
#
# Completa estas tareas usando Avogadro:

# %% [markdown]
# **Instrucciones**:
#
# 1. **Construir cafeína**:
#    - Abre Avogadro
#    - Construye la estructura de la cafeína (C₈H₁₀N₄O₂)
#    - Optimiza la geometría con MMFF94
#    - Verifica el peso molecular (194.19 g/mol)
#    - Guarda como `cafeina.xyz`
#
# 2. **Construir glicina** (aminoácido más simple):
#    - Construye H₂N-CH₂-COOH
#    - Optimiza
#    - Mide la distancia C-N
#    - Mide el ángulo H-N-C
#    - Guarda como `glicina.pdb`
#
# 3. **Explorar benceno**:
#    - Construye benceno (C₆H₆)
#    - Visualiza con diferentes estilos
#    - Mide la longitud de enlace C-C
#    - Calcula el momento dipolar (debe ser ~0)
#    - Guarda como `benceno.mol`
#
# **Responde**:
# - ¿Cuál es la distancia C-N en glicina?
# - ¿Todos los enlaces C-C en benceno son iguales?
# - ¿Qué diferencia hay entre optimizar con UFF vs MMFF94?

# %% [markdown]
# ### 📝 Ejercicio 4: Exploración con ChimeraX
#
# Si tienes ChimeraX instalado, realiza estas tareas:

# %% [markdown]
# **Instrucciones**:
#
# 1. **Visualizar ubiquitina**:
#    ```bash
#    open 1ubq
#    cartoon
#    color bychain
#    surface
#    transparency 70
#    save ubiquitina_cartoon.png
#    ```
#
# 2. **Analizar sitio activo de enzima**:
#    ```bash
#    open 3htb
#    cartoon
#    select ligand
#    show ligand atoms
#    style ligand stick
#    color ligand byhetero
#    select :* < 5 & ligand
#    show sel atoms
#    save sitio_activo.png
#    ```
#
# 3. **Comparar dos estructuras**:
#    ```bash
#    open 1ubq
#    open 1ubi
#    matchmaker #1 to #2
#    rmsd #1 to #2
#    ```
#
# **Responde**:
# - ¿Cuál es el RMSD entre 1UBQ y 1UBI?
# - ¿Qué residuos están cerca del ligando en 3HTB?
# - ¿Cómo se ve la superficie electrostática de ubiquitina?

# %% [markdown]
# ### 📝 Ejercicio 5: Proyecto Integrador
#
# Elige una molécula bioactiva y realiza un análisis completo:

# %%
# Ejercicio 5: Análisis completo de molécula bioactiva

# Ejemplos sugeridos:
# - Penicilina G: "CC1(C)SC2C(NC(=O)Cc3ccccc3)C(=O)N2C1C(=O)O"
# - Atorvastatina (Lipitor)
# - Sildenafil (Viagra)
# - Oseltamivir (Tamiflu)

molecula_elegida = ""  # TU CÓDIGO AQUÍ

# TU PROYECTO DEBE INCLUIR:
# 1. Generación de estructura 3D optimizada
# 2. Cálculo de propiedades (descriptores, Lipinski)
# 3. Visualización interactiva con Py3Dmol
# 4. Identificación de grupos funcionales
# 5. (Opcional) Construcción en Avogadro
# 6. (Opcional) Análisis en ChimeraX
# 7. Breve descripción de uso médico/biológico

# %% [markdown]
# ---
#
# ## 📊 Resumen y Conclusiones
#
# ### ✅ Lo que hemos aprendido
#
# En esta actividad has dominado:
# - **Py3Dmol**: Visualización interactiva en notebooks para moléculas y proteínas
# - **NGLView**: Herramienta especializada en biomoléculas y trayectorias
# - **Avogadro**: Editor molecular para construcción y optimización
# - **Chimera UCSF**: Visualización profesional y análisis estructural avanzado
# - **Estilos de representación**: Stick, ball & stick, surface, cartoon
# - **Flujo de trabajo**: Cuándo usar cada herramienta
#
# ### 🎯 Conceptos Clave
#
# | Herramienta | Fortaleza | Mejor uso |
# |-------------|-----------|-----------|
# | **Py3Dmol** | Integración con Python | Notebooks y visualización rápida |
# | **NGLView** | Biomoléculas | Análisis de proteínas en notebooks |
# | **Avogadro** | Edición molecular | Construcción y preparación de inputs |
# | **ChimeraX** | Análisis profesional | Investigación y publicaciones |
#
# ✅ **Habilidades adquiridas**:
# - Crear visualizaciones 3D interactivas desde código
# - Explorar estructuras de proteínas del PDB
# - Construir y editar moléculas manualmente
# - Generar imágenes de calidad para publicaciones
# - Realizar análisis estructural cuantitativo
#
# ✅ **Aplicaciones prácticas**:
# - Presentaciones científicas con visualizaciones 3D
# - Análisis de interacciones proteína-ligando
# - Construcción de moléculas para cálculos cuánticos
# - Exploración de estructuras cristalográficas
#
# ### 🚀 Próximos Pasos
# En la siguiente actividad exploraremos **Generación de Conformaciones Moleculares**, incluyendo búsqueda conformacional sistemática y métodos estocásticos.
#
# ---
#
# ## 📚 Referencias
#
# 1. **Py3Dmol**: Rego, N. & Koes, D. (2015). *Bioinformatics* 31, 1322–1324.
# 2. **NGLView**: Nguyen, H. et al. (2018). *Bioinformatics* 34, 1241–1242.
# 3. **Avogadro**: Hanwell, M. D. et al. (2012). *J. Cheminform.* 4, 17.
# 4. **UCSF ChimeraX**: Pettersen, E. F. et al. (2021). *Protein Science* 30, 70–82.
# 5. **3Dmol.js**: http://3dmol.csb.pitt.edu/
# 6. **Protein Data Bank**: https://www.rcsb.org/
#
# ---
#
# <div align="center">
#
# ## 🎉 ¡Felicitaciones!
#
# Has completado la **Actividad 2.4: Visualización 3D de Moléculas**
#
# **Siguiente actividad**: Generación de Conformaciones Moleculares
#
# [![Anterior](https://img.shields.io/badge/⬅️_Actividad_2.3-RDKit_y_OpenBabel-blue.svg)](03_rdkit_openbabel.ipynb)
# [![Siguiente](https://img.shields.io/badge/Actividad_2.5_➡️-Conformaciones-green.svg)](05_conformaciones.ipynb)
#
# ---
#
# 📚 **[Volver al Módulo 2](README.md)** | 🏠 **[Inicio del Curso](../README.md)**
#
# ---
#
# **Universidad de Caldas - Departamento de Química**
# *Química Computacional 173G7G*
#
# </div>
